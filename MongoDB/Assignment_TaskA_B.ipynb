# %% [markdown]
# # FIT5148 Assignment 2
#
#
# * Due: 24/05/2019
# * Tutor: Paras Sitoula, Wednesday 12-2pm
# <br>
#
# | Student 1 | Student 2|
# |-----------|----------|
# | Hitesh Get | Samuel Campbell |
#
# <br>
# <br>
#
# ### Task A MongoDB Data Model
#
# Climate Historic :
#
# <img src="Img1.PNG">
#
# Hotspot Historic:
#
# <img src="Img2.PNG">
#
# <dl>
# Above are two snapshots of the climate and hotspot datasets.
# <br>
#
# By looking at these data, we can see that the climate data has unique date values (a potential primary key). Whereas, in the hotspot data we can see multiple values of the date corresponding to the same timestamp values.
#
# So to relate these 2 datasets, we can use one-to-many relationships wherein the parent document can have multiple child documents, but child documents can only have one parent document.
#
# This can be achieved for MongoDB through the use of embedded or referenced documents. Now we need to choose which methodology would be better to design the model.
#
# Reference documents is preferred in scenarios where the data needs to be repeated across multiple documents: it becomes helpful to have them in separate document which in turn reduces errors and keeps the data consistent.
#
# Queries over embedded documents will run faster if they are spread over multiple documents, asMongoDB only needs to return one document instead of joining multiple documents in order to retrieve relationships. It also makes it easy to write simpler queries (as opposed to ad-hoc quasi-join-type queries).
#
# MongoDB can additionally only ensure atomicity at the document level. When multiple users are accessing the data, they might try to update the same columns with different data. With a model utilising embedded documents, MongoDB will ensure that there are no contradictory updates, avoiding conflict and maintaining a consistent data set.
#
# Hence, we are utilising the embedded model demonstrated below.
# <img src="Img3.PNG">
# </dl>
#
# <br>
# References : https://www.quackit.com/mongodb/tutorial/mongodb_create_a_relationship.cfm
# <br>

# %% [markdown]
# ### Task B
#
# <dl>
#     <dt><u>Please Note:</u></dt>
#     <dd>Where backticks are employed, they indicate that the contained value is the name of an object (i.e., \`var_1\`, \`collection_1\`).</dd>
#     <dd>For tasks 2B and 2D, it has been assumed that "between 65 and 100 degrees" is <i>not</i> inclusive of 65 and 100 degrees.</dd>
#     <dd>For task 2C, it has been assumed that, as surface temperature is requested as a returned variable, only climate data with recorded hotspots are relevant results.</dd>
#     <dd>For task 2E, although "records" has been specified as the return value, the 'full' records have not been returned: non-record hotspots have been removed for the reader's convenience</dd>
#     <dd>For task 2G, only records with at least one surface temperature have been returned (as a mean cannot be calculated from missing values) and the average surface temperature has been rounded to two decimal places</dd>
# </dl>

# %% [markdown]
# ## 1. Import Necessary Modules

# %%
import os
import sys
import csv
import json
import pymongo
from pymongo import MongoClient
from pprint import pprint

# %% [markdown]
# ## 2. Set Working Directory

# %%
# print("Please enter a valid path containing the climate and hotspot data") # /home/student/Downloads/Assignment Data-20190511/
# os.chdir(input())
os.chdir('/home/student/Downloads/Assignment Data-20190511/')

# %% [markdown]
# ## 3. Read and JSON-format Climate Data

# %%
# Read
climate_hist = open('./climate_historic.csv', 'r')

# Set up the data for iteration
reader_climate = csv.reader(climate_hist)
next(reader_climate)

# Instantiate bins
list_climate = []
dict_climate = {}

# Iterate through records
counter = 0
for i in reader_climate:
    """
    For each record:
        Assign an auto-incrementing `_id`;
        Assign `date`;
        Assign remaining variables as a list to `climate`, and;
        Instantiate an empty `hotspot` list.
    """
    dict_climate = {'_id': counter,  
                    'date': i[1],
                    'climate': {'station': int(i[0]), 
                               'air_temperature_celsius': int(i[2]), 
                               'relative_humidity': float(i[3]), 
                               'windspeed_knots': float(i[4]),
                               'max_wind_speed': float(i[5]),
                               'precipitation': i[6]},
                    'hotspot': []}
    
    counter = counter+1
    
    # Append to list of JSON-formatted records
    list_climate.append(dict_climate)

# %%
print("For your convenience, please find an example JSON-formatted climate record below:")
list_climate[0]
# Out:
# For your convenience, please find an example JSON-formatted climate record below:
# {'_id': 0,
#  'climate': {'air_temperature_celsius': 19,
#   'max_wind_speed': 11.1,
#   'precipitation': ' 0.00I',
#   'relative_humidity': 56.8,
#   'station': 948700,
#   'windspeed_knots': 7.9},
#  'date': '31/12/2016',
#  'hotspot': []}

# %% [markdown]
# ## 4. Read and JSON-format Hotspot Data

# %%
# Read
hotspot_hist = open('hotspot_historic.csv', 'r')

# Set up the data for iteration
reader_hotspot = csv.reader(hotspot_hist)
next(reader_hotspot)

# Instantiate bin
list_hotspot = []

# Iterate through records
prev_date = ''
for j in reader_hotspot: 
    """
    For each record:
        If that record's date was the last processed (it is only necessary to check against the last, as these data are ordered by date):
            Append to relevant record-set.
        Otherwise:
            Assign a `date`, and;
            Assign list of values to `hotspot`.
    """
    if j[4] == prev_date:
        dict_hotspot['hotspot'].append({'latitude': float(j[0]),
                                        'longitude': float(j[1]),
                                        'datetime': j[2],
                                        'confidence': int(j[3]),
                                        'surface_temperature_celsius': int(j[5])})
    else:
        dict_hotspot = {'date': j[4], 
                        'hotspot':[
                            {'latitude': float(j[0]),
                             'longitude': float(j[1]),
                             'datetime': j[2],
                             'confidence': int(j[3]),
                             'surface_temperature_celsius': int(j[5])}
                        ]} 
        
        list_hotspot.append(dict_hotspot)
        prev_date = j[4]

# %%
print("For your convenience, please find an example JSON-formatted hotspot record below:")
list_hotspot[0]
# Out:
# For your convenience, please find an example JSON-formatted hotspot record below:
# {'date': '27/12/2017',
#  'hotspot': [{'confidence': 78,
#    'datetime': '2017-12-27T04:16:51',
#    'latitude': -37.966,
#    'longitude': 145.051,
#    'surface_temperature_celsius': 68},
#   {'confidence': 82,
#    'datetime': '2017-12-27T00:02:15',
#    'latitude': -35.541,
#    'longitude': 143.311,
#    'surface_temperature_celsius': 63},
#   {'confidence': 67,
#    'datetime': '2017-12-27T00:02:15',
#    'latitude': -35.554,
#    'longitude': 143.307,
#    'surface_temperature_celsius': 53},
#   {'confidence': 86,
#    'datetime': '2017-12-27T00:02:14',
#    'latitude': -35.543,
#    'longitude': 143.316,
#    'surface_temperature_celsius': 67}]}

# %% [markdown]
# ## 5. Merge Records

# %%
# Iterate through both sets in a nested fashion, assigning hotspots to climate records with matching dates
for each in range(len(list_climate)):
    for item in range(len(list_hotspot)):
        if list_climate[each]['date'] == list_hotspot[item]['date']:
            list_climate[each]['hotspot'] = (list_hotspot[item]['hotspot'])

# %%
print("For your convenience, please find below an example merged record:")
list_climate[66]
# Out:
# For your convenience, please find below an example merged record:
# {'_id': 66,
#  'climate': {'air_temperature_celsius': 21,
#   'max_wind_speed': 13.0,
#   'precipitation': ' 0.00I',
#   'relative_humidity': 51.7,
#   'station': 948701,
#   'windspeed_knots': 7.2},
#  'date': '8/03/2017',
#  'hotspot': [{'confidence': 68,
#    'datetime': '2017-03-08T04:51:00',
#    'latitude': -37.7885,
#    'longitude': 141.9352,
#    'surface_temperature_celsius': 55},
#   {'confidence': 75,
#    'datetime': '2017-03-08T00:30:30',
#    'latitude': -38.1031,
#    'longitude': 142.4797,
#    'surface_temperature_celsius': 48}]}

# %% [markdown]
# ## 6. Backup JSON Output

# %%
with open('./climate_hotspot.json', 'w') as outfile:  
    json.dump(list_climate, outfile, indent = 5)

# %% [markdown]
# ## 7. Write JSON Output to MongoDB

# %%
# Connect to the database
client = MongoClient()
db = client.fit5148_db

# Delete collection if it already exists
db.climate.drop()

# Insert the merge set of record
db.climate.insert_many(list_climate)

# %%
print("For your convenience, please find below an example MongoDB record:", "\n")
pprint(db.climate.find({})[66])
# Out:
# For your convenience, please find below an example MongoDB record:
#
# {'_id': 66,
#  'climate': {'air_temperature_celsius': 21,
#              'max_wind_speed': 13.0,
#              'precipitation': ' 0.00I',
#              'relative_humidity': 51.7,
#              'station': 948701,
#              'windspeed_knots': 7.2},
#  'date': '8/03/2017',
#  'hotspot': [{'confidence': 68,
#               'datetime': '2017-03-08T04:51:00',
#               'latitude': -37.7885,
#               'longitude': 141.9352,
#               'surface_temperature_celsius': 55},
#              {'confidence': 75,
#               'datetime': '2017-03-08T00:30:30',
#               'latitude': -38.1031,
#               'longitude': 142.4797,
#               'surface_temperature_celsius': 48}]}

# %% [markdown]
# ## 8. (2A) Find Climate Data from the 10th of December, 2017

# %%
for i in db.climate.find({"date": "10/12/2017"}, {'climate': 1, '_id': 1}):
    pprint(i)
# Out:
# {'_id': 343,
#  'climate': {'air_temperature_celsius': 17,
#              'max_wind_speed': 14.0,
#              'precipitation': ' 0.00I',
#              'relative_humidity': 53.5,
#              'station': 948702,
#              'windspeed_knots': 7.3}}

# %% [markdown]
# ## 9. (2B) Find Latitudes, Longitudes, Surface Temperatures, and Confidences Where Surface Temperature Was Between 65 and 100 Degrees Celsius

# %%
for i in db.climate.aggregate([
    {'$match': {'hotspot.surface_temperature_celsius': {'$gt': 65, '$lt': 100}}},
    {'$unwind': '$hotspot'},
    {'$unwind': '$hotspot.surface_temperature_celsius'},
    {'$match': {'hotspot.surface_temperature_celsius': {'$gt': 65, '$lt': 100}}},
    {'$group': {
        '_id': '$_id',
        'hotspot': {'$addToSet': '$hotspot'}
    }},
    {'$project': {
        'hotspot.confidence': 1,
        'hotspot.latitude': 1,
        'hotspot.longitude': 1,
        'hotspot.surface_temperature_celsius': 1,
        '_id': 1
    }}
]):
    pprint(i)
# Out:
# {'_id': 347,
#  'hotspot': [{'confidence': 92,
#               'latitude': -37.95,
#               'longitude': 142.366,
#               'surface_temperature_celsius': 70}]}
# {'_id': 333,
#  'hotspot': [{'confidence': 95,
#               'latitude': -37.618,
#               'longitude': 149.281,
#               'surface_temperature_celsius': 76},
#              {'confidence': 99,
#               'latitude': -37.6,
#               'longitude': 149.325,
#               'surface_temperature_celsius': 86},
#              {'confidence': 98,
#               'latitude': -37.605,
#               'longitude': 149.302,
#               'surface_temperature_celsius': 83},
#              {'confidence': 100,
#               'latitude': -37.634,
#               'longitude': 149.237,
#               'surface_temperature_celsius': 71}]}
# {'_id': 332,
#  'hotspot': [{'confidence': 97,
#               'latitude': -37.61,
#               'longitude': 149.307,
#               'surface_temperature_celsius': 80},
#              {'confidence': 99,
#               'latitude': -37.609,
#               'longitude': 149.32,
#               'surface_temperature_celsius': 84},
#              {'confidence': 100,
#               'latitude': -37.606,
#               'longitude': 149.312,
#               'surface_temperature_celsius': 87}]}
# {'_id': 326,
#  'hotspot': [{'confidence': 93,
#               'latitude': -37.945,
#               'longitude': 144.354,
#               'surface_temperature_celsius': 73}]}
# {'_id': 315,
#  'hotspot': [{'confidence': 89,
#               'latitude': -36.94,
#               'longitude': 143.281,
#               'surface_temperature_celsius': 69}]}
# {'_id': 289,
#  'hotspot': [{'confidence': 91,
#               'latitude': -37.247,
#               'longitude': 141.278,
#               'surface_temperature_celsius': 68}]}
# {'_id': 282,
#  'hotspot': [{'confidence': 96,
#               'latitude': -38.127,
#               'longitude': 143.82,
#               'surface_temperature_celsius': 77}]}
# {'_id': 265,
#  'hotspot': [{'confidence': 100,
#               'latitude': -37.401,
#               'longitude': 148.067,
#               'surface_temperature_celsius': 79},
#              {'confidence': 100,
#               'latitude': -37.399,
#               'longitude': 148.081,
#               'surface_temperature_celsius': 84},
#              {'confidence': 62,
#               'latitude': -37.379,
#               'longitude': 148.132,
#               'surface_temperature_celsius': 78},
#              {'confidence': 58,
#               'latitude': -37.379,
#               'longitude': 148.126,
#               'surface_temperature_celsius': 82}]}
# {'_id': 105,
#  'hotspot': [{'confidence': 91,
#               'latitude': -36.7651,
#               'longitude': 143.5801,
#               'surface_temperature_celsius': 68}]}
# {'_id': 293,
#  'hotspot': [{'confidence': 92,
#               'latitude': -36.098,
#               'longitude': 143.74,
#               'surface_temperature_celsius': 67}]}
# {'_id': 129,
#  'hotspot': [{'confidence': 99,
#               'latitude': -37.5867,
#               'longitude': 143.6256,
#               'surface_temperature_celsius': 85},
#              {'confidence': 94,
#               'latitude': -37.4357,
#               'longitude': 142.7813,
#               'surface_temperature_celsius': 74},
#              {'confidence': 98,
#               'latitude': -38.2853,
#               'longitude': 145.9519,
#               'surface_temperature_celsius': 83},
#              {'confidence': 99,
#               'latitude': -38.0881,
#               'longitude': 143.9391,
#               'surface_temperature_celsius': 84},
#              {'confidence': 96,
#               'latitude': -38.0866,
#               'longitude': 143.9534,
#               'surface_temperature_celsius': 78},
#              {'confidence': 98,
#               'latitude': -38.2375,
#               'longitude': 142.8363,
#               'surface_temperature_celsius': 82},
#              {'confidence': 84,
#               'latitude': -37.8323,
#               'longitude': 147.2232,
#               'surface_temperature_celsius': 68},
#              {'confidence': 96,
#               'latitude': -36.8094,
#               'longitude': 142.8885,
#               'surface_temperature_celsius': 77},
#              {'confidence': 96,
#               'latitude': -36.3438,
#               'longitude': 141.5832,
#               'surface_temperature_celsius': 78},
#              {'confidence': 92,
#               'latitude': -37.4463,
#               'longitude': 142.7829,
#               'surface_temperature_celsius': 70},
#              {'confidence': 95,
#               'latitude': -37.6854,
#               'longitude': 143.4543,
#               'surface_temperature_celsius': 76},
#              {'confidence': 92,
#               'latitude': -38.2391,
#               'longitude': 142.82,
#               'surface_temperature_celsius': 71},
#              {'confidence': 100,
#               'latitude': -38.5123,
#               'longitude': 146.4007,
#               'surface_temperature_celsius': 89}]}
# {'_id': 104,
#  'hotspot': [{'confidence': 96,
#               'latitude': -36.8298,
#               'longitude': 143.4483,
#               'surface_temperature_celsius': 79},
#              {'confidence': 96,
#               'latitude': -36.1898,
#               'longitude': 145.0922,
#               'surface_temperature_celsius': 78},
#              {'confidence': 100,
#               'latitude': -36.8283,
#               'longitude': 143.4605,
#               'surface_temperature_celsius': 93},
#              {'confidence': 93,
#               'latitude': -36.8238,
#               'longitude': 143.5724,
#               'surface_temperature_celsius': 73},
#              {'confidence': 100,
#               'latitude': -36.6615,
#               'longitude': 144.6014,
#               'surface_temperature_celsius': 90},
#              {'confidence': 99,
#               'latitude': -35.8276,
#               'longitude': 143.7549,
#               'surface_temperature_celsius': 85},
#              {'confidence': 78,
#               'latitude': -35.9326,
#               'longitude': 141.958,
#               'surface_temperature_celsius': 66},
#              {'confidence': 97,
#               'latitude': -36.6527,
#               'longitude': 142.7392,
#               'surface_temperature_celsius': 81},
#              {'confidence': 98,
#               'latitude': -36.9329,
#               'longitude': 143.7796,
#               'surface_temperature_celsius': 82},
#              {'confidence': 91,
#               'latitude': -36.6892,
#               'longitude': 145.2775,
#               'surface_temperature_celsius': 69}]}
# {'_id': 103,
#  'hotspot': [{'confidence': 100,
#               'latitude': -36.7957,
#               'longitude': 143.9652,
#               'surface_temperature_celsius': 87},
#              {'confidence': 75,
#               'latitude': -36.7499,
#               'longitude': 141.3006,
#               'surface_temperature_celsius': 99},
#              {'confidence': 84,
#               'latitude': -36.7432,
#               'longitude': 141.3296,
#               'surface_temperature_celsius': 79},
#              {'confidence': 84,
#               'latitude': -36.7531,
#               'longitude': 141.3253,
#               'surface_temperature_celsius': 78},
#              {'confidence': 99,
#               'latitude': -36.7943,
#               'longitude': 143.9571,
#               'surface_temperature_celsius': 84}]}
# {'_id': 102,
#  'hotspot': [{'confidence': 95,
#               'latitude': -36.1418,
#               'longitude': 144.0261,
#               'surface_temperature_celsius': 76},
#              {'confidence': 90,
#               'latitude': -36.5532,
#               'longitude': 142.5349,
#               'surface_temperature_celsius': 67},
#              {'confidence': 100,
#               'latitude': -36.3972,
#               'longitude': 141.6041,
#               'surface_temperature_celsius': 90},
#              {'confidence': 92,
#               'latitude': -36.0749,
#               'longitude': 143.4058,
#               'surface_temperature_celsius': 70},
#              {'confidence': 90,
#               'latitude': -36.2857,
#               'longitude': 141.3467,
#               'surface_temperature_celsius': 67},
#              {'confidence': 94,
#               'latitude': -36.3313,
#               'longitude': 141.0017,
#               'surface_temperature_celsius': 73},
#              {'confidence': 100,
#               'latitude': -35.8182,
#               'longitude': 143.8739,
#               'surface_temperature_celsius': 92},
#              {'confidence': 95,
#               'latitude': -37.9152,
#               'longitude': 145.8808,
#               'surface_temperature_celsius': 77},
#              {'confidence': 100,
#               'latitude': -37.9174,
#               'longitude': 145.8678,
#               'surface_temperature_celsius': 93},
#              {'confidence': 100,
#               'latitude': -35.6469,
#               'longitude': 142.376,
#               'surface_temperature_celsius': 93},
#              {'confidence': 95,
#               'latitude': -35.0706,
#               'longitude': 141.4435,
#               'surface_temperature_celsius': 75},
#              {'confidence': 100,
#               'latitude': -38.0254,
#               'longitude': 142.3959,
#               'surface_temperature_celsius': 99},
#              {'confidence': 100,
#               'latitude': -37.1999,
#               'longitude': 143.8231,
#               'surface_temperature_celsius': 90},
#              {'confidence': 97,
#               'latitude': -36.601,
#               'longitude': 144.6378,
#               'surface_temperature_celsius': 80},
#              {'confidence': 100,
#               'latitude': -36.7089,
#               'longitude': 143.3518,
#               'surface_temperature_celsius': 93},
#              {'confidence': 90,
#               'latitude': -36.1462,
#               'longitude': 145.2096,
#               'surface_temperature_celsius': 66},
#              {'confidence': 91,
#               'latitude': -36.1748,
#               'longitude': 145.7582,
#               'surface_temperature_celsius': 69},
#              {'confidence': 95,
#               'latitude': -37.8906,
#               'longitude': 146.2035,
#               'surface_temperature_celsius': 75},
#              {'confidence': 95,
#               'latitude': -36.8681,
#               'longitude': 143.5186,
#               'surface_temperature_celsius': 76},
#              {'confidence': 100,
#               'latitude': -36.0837,
#               'longitude': 144.2448,
#               'surface_temperature_celsius': 87},
#              {'confidence': 84,
#               'latitude': -37.7587,
#               'longitude': 142.8521,
#               'surface_temperature_celsius': 80},
#              {'confidence': 100,
#               'latitude': -37.0899,
#               'longitude': 141.0238,
#               'surface_temperature_celsius': 90},
#              {'confidence': 91,
#               'latitude': -37.4611,
#               'longitude': 144.9371,
#               'surface_temperature_celsius': 69},
#              {'confidence': 91,
#               'latitude': -37.6171,
#               'longitude': 142.9426,
#               'surface_temperature_celsius': 68},
#              {'confidence': 90,
#               'latitude': -36.429,
#               'longitude': 141.5759,
#               'surface_temperature_celsius': 67},
#              {'confidence': 90,
#               'latitude': -37.8185,
#               'longitude': 142.5609,
#               'surface_temperature_celsius': 66},
#              {'confidence': 98,
#               'latitude': -36.2948,
#               'longitude': 141.3486,
#               'surface_temperature_celsius': 82},
#              {'confidence': 100,
#               'latitude': -37.9246,
#               'longitude': 146.2464,
#               'surface_temperature_celsius': 96},
#              {'confidence': 92,
#               'latitude': -36.1346,
#               'longitude': 145.2196,
#               'surface_temperature_celsius': 71},
#              {'confidence': 89,
#               'latitude': -35.8071,
#               'longitude': 142.7318,
#               'surface_temperature_celsius': 66},
#              {'confidence': 100,
#               'latitude': -38.0795,
#               'longitude': 143.2449,
#               'surface_temperature_celsius': 91},
#              {'confidence': 95,
#               'latitude': -36.3823,
#               'longitude': 141.3146,
#               'surface_temperature_celsius': 77},
#              {'confidence': 92,
#               'latitude': -36.9364,
#               'longitude': 143.4996,
#               'surface_temperature_celsius': 70},
#              {'confidence': 100,
#               'latitude': -36.4125,
#               'longitude': 143.1189,
#               'surface_temperature_celsius': 92},
#              {'confidence': 100,
#               'latitude': -38.027,
#               'longitude': 142.3844,
#               'surface_temperature_celsius': 95},
#              {'confidence': 100,
#               'latitude': -36.3999,
#               'longitude': 144.737,
#               'surface_temperature_celsius': 88},
#              {'confidence': 99,
#               'latitude': -36.0691,
#               'longitude': 145.7797,
#               'surface_temperature_celsius': 85},
#              {'confidence': 100,
#               'latitude': -37.0761,
#               'longitude': 141.0574,
#               'surface_temperature_celsius': 89},
#              {'confidence': 99,
#               'latitude': -37.8885,
#               'longitude': 143.9157,
#               'surface_temperature_celsius': 85},
#              {'confidence': 100,
#               'latitude': -36.4142,
#               'longitude': 143.1077,
#               'surface_temperature_celsius': 97},
#              {'confidence': 93,
#               'latitude': -35.0616,
#               'longitude': 141.4417,
#               'surface_temperature_celsius': 73},
#              {'confidence': 96,
#               'latitude': -36.1518,
#               'longitude': 144.0233,
#               'surface_temperature_celsius': 79},
#              {'confidence': 93,
#               'latitude': -36.5243,
#               'longitude': 142.0839,
#               'surface_temperature_celsius': 72},
#              {'confidence': 100,
#               'latitude': -35.6374,
#               'longitude': 142.3787,
#               'surface_temperature_celsius': 95},
#              {'confidence': 91,
#               'latitude': -35.6453,
#               'longitude': 142.387,
#               'surface_temperature_celsius': 69},
#              {'confidence': 97,
#               'latitude': -37.0669,
#               'longitude': 141.0556,
#               'surface_temperature_celsius': 80},
#              {'confidence': 96,
#               'latitude': -36.9498,
#               'longitude': 142.2012,
#               'surface_temperature_celsius': 78},
#              {'confidence': 90,
#               'latitude': -36.5399,
#               'longitude': 144.678,
#               'surface_temperature_celsius': 66},
#              {'confidence': 97,
#               'latitude': -36.7787,
#               'longitude': 141.4449,
#               'surface_temperature_celsius': 80},
#              {'confidence': 98,
#               'latitude': -37.618,
#               'longitude': 143.0013,
#               'surface_temperature_celsius': 82},
#              {'confidence': 100,
#               'latitude': -36.1771,
#               'longitude': 145.7451,
#               'surface_temperature_celsius': 93},
#              {'confidence': 90,
#               'latitude': -36.8867,
#               'longitude': 142.1873,
#               'surface_temperature_celsius': 66},
#              {'confidence': 91,
#               'latitude': -36.4449,
#               'longitude': 140.9836,
#               'surface_temperature_celsius': 68},
#              {'confidence': 100,
#               'latitude': -37.3847,
#               'longitude': 142.8935,
#               'surface_temperature_celsius': 88},
#              {'confidence': 92,
#               'latitude': -36.1367,
#               'longitude': 145.2071,
#               'surface_temperature_celsius': 71},
#              {'confidence': 91,
#               'latitude': -36.4612,
#               'longitude': 144.7775,
#               'surface_temperature_celsius': 80},
#              {'confidence': 90,
#               'latitude': -36.8835,
#               'longitude': 142.2098,
#               'surface_temperature_celsius': 67},
#              {'confidence': 100,
#               'latitude': -36.4409,
#               'longitude': 141.6948,
#               'surface_temperature_celsius': 92},
#              {'confidence': 94,
#               'latitude': -36.2933,
#               'longitude': 141.36,
#               'surface_temperature_celsius': 75},
#              {'confidence': 90,
#               'latitude': -35.1949,
#               'longitude': 141.0622,
#               'surface_temperature_celsius': 66},
#              {'confidence': 100,
#               'latitude': -37.4591,
#               'longitude': 144.9492,
#               'surface_temperature_celsius': 89},
#              {'confidence': 100,
#               'latitude': -36.91,
#               'longitude': 141.2705,
#               'surface_temperature_celsius': 96},
#              {'confidence': 100,
#               'latitude': -36.4518,
#               'longitude': 144.7752,
#               'surface_temperature_celsius': 97},
#              {'confidence': 97,
#               'latitude': -36.8158,
#               'longitude': 142.6229,
#               'surface_temperature_celsius': 80},
#              {'confidence': 92,
#               'latitude': -36.1924,
#               'longitude': 143.1716,
#               'surface_temperature_celsius': 70},
#              {'confidence': 92,
#               'latitude': -36.0714,
#               'longitude': 145.7665,
#               'surface_temperature_celsius': 71},
#              {'confidence': 90,
#               'latitude': -36.7903,
#               'longitude': 141.618,
#               'surface_temperature_celsius': 67},
#              {'confidence': 97,
#               'latitude': -36.1067,
#               'longitude': 143.7948,
#               'surface_temperature_celsius': 79},
#              {'confidence': 91,
#               'latitude': -36.3487,
#               'longitude': 145.5315,
#               'surface_temperature_celsius': 68},
#              {'confidence': 94,
#               'latitude': -36.4816,
#               'longitude': 141.6635,
#               'surface_temperature_celsius': 75},
#              {'confidence': 100,
#               'latitude': -35.1857,
#               'longitude': 141.0604,
#               'surface_temperature_celsius': 92},
#              {'confidence': 93,
#               'latitude': -36.1941,
#               'longitude': 143.1604,
#               'surface_temperature_celsius': 72},
#              {'confidence': 90,
#               'latitude': -36.782,
#               'longitude': 141.8851,
#               'surface_temperature_celsius': 67},
#              {'confidence': 92,
#               'latitude': -36.5586,
#               'longitude': 144.0423,
#               'surface_temperature_celsius': 71},
#              {'confidence': 90,
#               'latitude': -36.5568,
#               'longitude': 144.0538,
#               'surface_temperature_celsius': 68},
#              {'confidence': 97,
#               'latitude': -36.4538,
#               'longitude': 144.763,
#               'surface_temperature_celsius': 81}]}
# {'_id': 170,
#  'hotspot': [{'confidence': 97,
#               'latitude': -36.369,
#               'longitude': 143.7132,
#               'surface_temperature_celsius': 80},
#              {'confidence': 100,
#               'latitude': -36.3756,
#               'longitude': 143.7243,
#               'surface_temperature_celsius': 88},
#              {'confidence': 100,
#               'latitude': -36.3799,
#               'longitude': 143.7149,
#               'surface_temperature_celsius': 89},
#              {'confidence': 91,
#               'latitude': -36.3774,
#               'longitude': 143.7079,
#               'surface_temperature_celsius': 68}]}
# {'_id': 101,
#  'hotspot': [{'confidence': 93,
#               'latitude': -36.4489,
#               'longitude': 144.7685,
#               'surface_temperature_celsius': 73},
#              {'confidence': 93,
#               'latitude': -36.6823,
#               'longitude': 142.5024,
#               'surface_temperature_celsius': 71},
#              {'confidence': 100,
#               'latitude': -37.8249,
#               'longitude': 143.6174,
#               'surface_temperature_celsius': 98},
#              {'confidence': 92,
#               'latitude': -37.4033,
#               'longitude': 143.6884,
#               'surface_temperature_celsius': 70},
#              {'confidence': 94,
#               'latitude': -37.5812,
#               'longitude': 142.7374,
#               'surface_temperature_celsius': 75},
#              {'confidence': 100,
#               'latitude': -37.5949,
#               'longitude': 142.6857,
#               'surface_temperature_celsius': 98},
#              {'confidence': 95,
#               'latitude': -37.8247,
#               'longitude': 143.6243,
#               'surface_temperature_celsius': 77},
#              {'confidence': 95,
#               'latitude': -37.4028,
#               'longitude': 143.6932,
#               'surface_temperature_celsius': 75}]}
# {'_id': 97,
#  'hotspot': [{'confidence': 90,
#               'latitude': -36.7165,
#               'longitude': 142.6155,
#               'surface_temperature_celsius': 66},
#              {'confidence': 66,
#               'latitude': -37.3493,
#               'longitude': 149.3691,
#               'surface_temperature_celsius': 80},
#              {'confidence': 99,
#               'latitude': -36.7287,
#               'longitude': 142.6017,
#               'surface_temperature_celsius': 85},
#              {'confidence': 91,
#               'latitude': -35.2363,
#               'longitude': 143.0004,
#               'surface_temperature_celsius': 69},
#              {'confidence': 98,
#               'latitude': -35.2381,
#               'longitude': 142.994,
#               'surface_temperature_celsius': 83},
#              {'confidence': 67,
#               'latitude': -37.34,
#               'longitude': 149.3668,
#               'surface_temperature_celsius': 74},
#              {'confidence': 100,
#               'latitude': -35.2378,
#               'longitude': 142.9864,
#               'surface_temperature_celsius': 94}]}
# {'_id': 96,
#  'hotspot': [{'confidence': 95,
#               'latitude': -37.224,
#               'longitude': 147.4347,
#               'surface_temperature_celsius': 76},
#              {'confidence': 100,
#               'latitude': -37.2168,
#               'longitude': 147.4748,
#               'surface_temperature_celsius': 89},
#              {'confidence': 96,
#               'latitude': -37.222,
#               'longitude': 147.4689,
#               'surface_temperature_celsius': 78},
#              {'confidence': 92,
#               'latitude': -37.2082,
#               'longitude': 147.4368,
#               'surface_temperature_celsius': 70},
#              {'confidence': 92,
#               'latitude': -37.2063,
#               'longitude': 147.4713,
#               'surface_temperature_celsius': 70}]}
# {'_id': 154,
#  'hotspot': [{'confidence': 91,
#               'latitude': -36.7801,
#               'longitude': 142.7151,
#               'surface_temperature_celsius': 68},
#              {'confidence': 91,
#               'latitude': -36.7685,
#               'longitude': 142.7134,
#               'surface_temperature_celsius': 69}]}
# {'_id': 95,
#  'hotspot': [{'confidence': 86,
#               'latitude': -36.6986,
#               'longitude': 142.7259,
#               'surface_temperature_celsius': 72},
#              {'confidence': 100,
#               'latitude': -37.782,
#               'longitude': 148.3844,
#               'surface_temperature_celsius': 99},
#              {'confidence': 100,
#               'latitude': -36.9918,
#               'longitude': 141.8667,
#               'surface_temperature_celsius': 97},
#              {'confidence': 93,
#               'latitude': -37.5888,
#               'longitude': 148.5949,
#               'surface_temperature_celsius': 72},
#              {'confidence': 92,
#               'latitude': -36.6334,
#               'longitude': 142.2244,
#               'surface_temperature_celsius': 69},
#              {'confidence': 92,
#               'latitude': -36.0157,
#               'longitude': 145.9414,
#               'surface_temperature_celsius': 70},
#              {'confidence': 92,
#               'latitude': -37.8161,
#               'longitude': 142.9286,
#               'surface_temperature_celsius': 71},
#              {'confidence': 76,
#               'latitude': -37.7966,
#               'longitude': 142.3196,
#               'surface_temperature_celsius': 66},
#              {'confidence': 94,
#               'latitude': -38.0052,
#               'longitude': 142.6179,
#               'surface_temperature_celsius': 89},
#              {'confidence': 90,
#               'latitude': -36.6384,
#               'longitude': 142.4075,
#               'surface_temperature_celsius': 66},
#              {'confidence': 100,
#               'latitude': -36.9034,
#               'longitude': 141.0013,
#               'surface_temperature_celsius': 95},
#              {'confidence': 91,
#               'latitude': -37.3803,
#               'longitude': 145.611,
#               'surface_temperature_celsius': 68},
#              {'confidence': 90,
#               'latitude': -36.0387,
#               'longitude': 145.6787,
#               'surface_temperature_celsius': 67},
#              {'confidence': 100,
#               'latitude': -37.8429,
#               'longitude': 143.8366,
#               'surface_temperature_celsius': 88},
#              {'confidence': 100,
#               'latitude': -35.805,
#               'longitude': 142.1326,
#               'surface_temperature_celsius': 95},
#              {'confidence': 90,
#               'latitude': -37.5788,
#               'longitude': 148.592,
#               'surface_temperature_celsius': 67},
#              {'confidence': 91,
#               'latitude': -36.031,
#               'longitude': 145.6824,
#               'surface_temperature_celsius': 69},
#              {'confidence': 94,
#               'latitude': -36.6349,
#               'longitude': 142.2125,
#               'surface_temperature_celsius': 86},
#              {'confidence': 86,
#               'latitude': -37.5814,
#               'longitude': 148.5777,
#               'surface_temperature_celsius': 68},
#              {'confidence': 94,
#               'latitude': -35.811,
#               'longitude': 142.1403,
#               'surface_temperature_celsius': 96},
#              {'confidence': 81,
#               'latitude': -36.0844,
#               'longitude': 141.4934,
#               'surface_temperature_celsius': 71},
#              {'confidence': 83,
#               'latitude': -37.803,
#               'longitude': 142.3151,
#               'surface_temperature_celsius': 78},
#              {'confidence': 99,
#               'latitude': -37.777,
#               'longitude': 148.4128,
#               'surface_temperature_celsius': 85},
#              {'confidence': 96,
#               'latitude': -37.7542,
#               'longitude': 142.9949,
#               'surface_temperature_celsius': 77},
#              {'confidence': 90,
#               'latitude': -36.1104,
#               'longitude': 145.9829,
#               'surface_temperature_celsius': 76},
#              {'confidence': 97,
#               'latitude': -37.7617,
#               'longitude': 143.081,
#               'surface_temperature_celsius': 81}]}
# {'_id': 72,
#  'hotspot': [{'confidence': 94,
#               'latitude': -34.3555,
#               'longitude': 141.5495,
#               'surface_temperature_celsius': 75},
#              {'confidence': 93,
#               'latitude': -34.3539,
#               'longitude': 141.5547,
#               'surface_temperature_celsius': 72},
#              {'confidence': 90,
#               'latitude': -34.357,
#               'longitude': 141.5361,
#               'surface_temperature_celsius': 67},
#              {'confidence': 95,
#               'latitude': -36.9959,
#               'longitude': 148.2118,
#               'surface_temperature_celsius': 75},
#              {'confidence': 96,
#               'latitude': -34.3554,
#               'longitude': 141.5413,
#               'surface_temperature_celsius': 79},
#              {'confidence': 90,
#               'latitude': -36.9939,
#               'longitude': 148.2244,
#               'surface_temperature_celsius': 68}]}
# {'_id': 349,
#  'hotspot': [{'confidence': 90,
#               'latitude': -37.624,
#               'longitude': 149.314,
#               'surface_temperature_celsius': 66},
#              {'confidence': 93,
#               'latitude': -38.057,
#               'longitude': 144.211,
#               'surface_temperature_celsius': 73},
#              {'confidence': 95,
#               'latitude': -37.613,
#               'longitude': 149.305,
#               'surface_temperature_celsius': 75},
#              {'confidence': 93,
#               'latitude': -37.875,
#               'longitude': 142.51,
#               'surface_temperature_celsius': 73}]}
# {'_id': 94,
#  'hotspot': [{'confidence': 100,
#               'latitude': -37.4343,
#               'longitude': 147.6327,
#               'surface_temperature_celsius': 92},
#              {'confidence': 95,
#               'latitude': -37.4323,
#               'longitude': 147.6583,
#               'surface_temperature_celsius': 76},
#              {'confidence': 87,
#               'latitude': -37.6387,
#               'longitude': 142.9032,
#               'surface_temperature_celsius': 88},
#              {'confidence': 90,
#               'latitude': -37.7835,
#               'longitude': 148.4138,
#               'surface_temperature_celsius': 66},
#              {'confidence': 93,
#               'latitude': -37.3165,
#               'longitude': 147.4932,
#               'surface_temperature_celsius': 72},
#              {'confidence': 93,
#               'latitude': -37.6439,
#               'longitude': 142.913,
#               'surface_temperature_celsius': 83},
#              {'confidence': 95,
#               'latitude': -37.3158,
#               'longitude': 147.4986,
#               'surface_temperature_celsius': 76}]}
# {'_id': 157,
#  'hotspot': [{'confidence': 90,
#               'latitude': -36.4325,
#               'longitude': 144.3142,
#               'surface_temperature_celsius': 67},
#              {'confidence': 96,
#               'latitude': -36.1002,
#               'longitude': 142.3405,
#               'surface_temperature_celsius': 78}]}
# {'_id': 106,
#  'hotspot': [{'confidence': 90,
#               'latitude': -37.1349,
#               'longitude': 141.9491,
#               'surface_temperature_celsius': 67},
#              {'confidence': 94,
#               'latitude': -36.3966,
#               'longitude': 141.406,
#               'surface_temperature_celsius': 74},
#              {'confidence': 91,
#               'latitude': -37.0782,
#               'longitude': 145.3625,
#               'surface_temperature_celsius': 68},
#              {'confidence': 95,
#               'latitude': -36.5199,
#               'longitude': 144.7311,
#               'surface_temperature_celsius': 77}]}
# {'_id': 131,
#  'hotspot': [{'confidence': 93,
#               'latitude': -37.4671,
#               'longitude': 145.9962,
#               'surface_temperature_celsius': 73}]}
# {'_id': 83,
#  'hotspot': [{'confidence': 100,
#               'latitude': -37.8881,
#               'longitude': 145.8229,
#               'surface_temperature_celsius': 99},
#              {'confidence': 95,
#               'latitude': -37.8774,
#               'longitude': 145.8213,
#               'surface_temperature_celsius': 77},
#              {'confidence': 95,
#               'latitude': -37.7805,
#               'longitude': 143.5003,
#               'surface_temperature_celsius': 75}]}
# {'_id': 132,
#  'hotspot': [{'confidence': 100,
#               'latitude': -36.1506,
#               'longitude': 143.5671,
#               'surface_temperature_celsius': 95},
#              {'confidence': 90,
#               'latitude': -35.6871,
#               'longitude': 143.5235,
#               'surface_temperature_celsius': 68},
#              {'confidence': 91,
#               'latitude': -35.6819,
#               'longitude': 143.5275,
#               'surface_temperature_celsius': 69},
#              {'confidence': 91,
#               'latitude': -36.5541,
#               'longitude': 144.1321,
#               'surface_temperature_celsius': 69},
#              {'confidence': 94,
#               'latitude': -36.0828,
#               'longitude': 145.873,
#               'surface_temperature_celsius': 75},
#              {'confidence': 95,
#               'latitude': -36.3254,
#               'longitude': 144.3638,
#               'surface_temperature_celsius': 77},
#              {'confidence': 100,
#               'latitude': -36.0816,
#               'longitude': 145.859,
#               'surface_temperature_celsius': 98},
#              {'confidence': 100,
#               'latitude': -36.1532,
#               'longitude': 143.5527,
#               'surface_temperature_celsius': 90},
#              {'confidence': 100,
#               'latitude': -36.0077,
#               'longitude': 141.7747,
#               'surface_temperature_celsius': 93}]}
# {'_id': 75,
#  'hotspot': [{'confidence': 94,
#               'latitude': -36.7152,
#               'longitude': 141.3853,
#               'surface_temperature_celsius': 74}]}
# {'_id': 93,
#  'hotspot': [{'confidence': 87,
#               'latitude': -36.0973,
#               'longitude': 143.4279,
#               'surface_temperature_celsius': 92},
#              {'confidence': 79,
#               'latitude': -36.883,
#               'longitude': 142.1637,
#               'surface_temperature_celsius': 67},
#              {'confidence': 93,
#               'latitude': -37.0769,
#               'longitude': 141.042,
#               'surface_temperature_celsius': 72},
#              {'confidence': 97,
#               'latitude': -36.1925,
#               'longitude': 145.93,
#               'surface_temperature_celsius': 79},
#              {'confidence': 85,
#               'latitude': -36.111,
#               'longitude': 145.124,
#               'surface_temperature_celsius': 66},
#              {'confidence': 90,
#               'latitude': -36.1615,
#               'longitude': 141.8728,
#               'surface_temperature_celsius': 66},
#              {'confidence': 92,
#               'latitude': -36.5989,
#               'longitude': 141.9771,
#               'surface_temperature_celsius': 81},
#              {'confidence': 64,
#               'latitude': -36.6281,
#               'longitude': 142.4349,
#               'surface_temperature_celsius': 68},
#              {'confidence': 96,
#               'latitude': -36.6006,
#               'longitude': 141.9657,
#               'surface_temperature_celsius': 78},
#              {'confidence': 85,
#               'latitude': -35.4533,
#               'longitude': 143.2029,
#               'surface_temperature_celsius': 66},
#              {'confidence': 90,
#               'latitude': -35.4033,
#               'longitude': 143.267,
#               'surface_temperature_celsius': 67},
#              {'confidence': 100,
#               'latitude': -37.3735,
#               'longitude': 145.8384,
#               'surface_temperature_celsius': 95},
#              {'confidence': 96,
#               'latitude': -36.1955,
#               'longitude': 145.914,
#               'surface_temperature_celsius': 78},
#              {'confidence': 98,
#               'latitude': -36.095,
#               'longitude': 141.7699,
#               'surface_temperature_celsius': 82},
#              {'confidence': 90,
#               'latitude': -36.1122,
#               'longitude': 142.1491,
#               'surface_temperature_celsius': 76},
#              {'confidence': 100,
#               'latitude': -36.1819,
#               'longitude': 145.9269,
#               'surface_temperature_celsius': 98},
#              {'confidence': 66,
#               'latitude': -36.6299,
#               'longitude': 142.4234,
#               'surface_temperature_celsius': 71}]}
# {'_id': 70,
#  'hotspot': [{'confidence': 85,
#               'latitude': -37.4128,
#               'longitude': 147.0242,
#               'surface_temperature_celsius': 98},
#              {'confidence': 80,
#               'latitude': -37.0055,
#               'longitude': 148.1582,
#               'surface_temperature_celsius': 68},
#              {'confidence': 100,
#               'latitude': -37.4229,
#               'longitude': 147.027,
#               'surface_temperature_celsius': 99},
#              {'confidence': 84,
#               'latitude': -37.0193,
#               'longitude': 148.1459,
#               'surface_temperature_celsius': 71}]}
# {'_id': 341,
#  'hotspot': [{'confidence': 100,
#               'latitude': -36.282,
#               'longitude': 146.157,
#               'surface_temperature_celsius': 71}]}
# {'_id': 92,
#  'hotspot': [{'confidence': 93,
#               'latitude': -37.3046,
#               'longitude': 143.5448,
#               'surface_temperature_celsius': 72},
#              {'confidence': 87,
#               'latitude': -37.7974,
#               'longitude': 145.9535,
#               'surface_temperature_celsius': 97},
#              {'confidence': 96,
#               'latitude': -37.3704,
#               'longitude': 145.8942,
#               'surface_temperature_celsius': 78},
#              {'confidence': 95,
#               'latitude': -37.8072,
#               'longitude': 145.9738,
#               'surface_temperature_celsius': 77},
#              {'confidence': 100,
#               'latitude': -37.297,
#               'longitude': 143.5753,
#               'surface_temperature_celsius': 93},
#              {'confidence': 87,
#               'latitude': -37.3735,
#               'longitude': 145.886,
#               'surface_temperature_celsius': 96},
#              {'confidence': 90,
#               'latitude': -35.7657,
#               'longitude': 142.0906,
#               'surface_temperature_celsius': 66},
#              {'confidence': 100,
#               'latitude': -37.2988,
#               'longitude': 143.5487,
#               'surface_temperature_celsius': 90},
#              {'confidence': 100,
#               'latitude': -37.3025,
#               'longitude': 143.5714,
#               'surface_temperature_celsius': 98},
#              {'confidence': 100,
#               'latitude': -37.383,
#               'longitude': 145.9089,
#               'surface_temperature_celsius': 89},
#              {'confidence': 95,
#               'latitude': -36.4312,
#               'longitude': 141.2064,
#               'surface_temperature_celsius': 76},
#              {'confidence': 99,
#               'latitude': -37.7236,
#               'longitude': 143.3995,
#               'surface_temperature_celsius': 86},
#              {'confidence': 93,
#               'latitude': -37.7465,
#               'longitude': 143.3806,
#               'surface_temperature_celsius': 72},
#              {'confidence': 98,
#               'latitude': -37.7509,
#               'longitude': 143.4023,
#               'surface_temperature_celsius': 82},
#              {'confidence': 89,
#               'latitude': -37.7446,
#               'longitude': 143.4085,
#               'surface_temperature_celsius': 66}]}
# {'_id': 68,
#  'hotspot': [{'confidence': 97,
#               'latitude': -37.6572,
#               'longitude': 142.0703,
#               'surface_temperature_celsius': 80},
#              {'confidence': 94,
#               'latitude': -37.2284,
#               'longitude': 147.9187,
#               'surface_temperature_celsius': 73}]}
# {'_id': 76,
#  'hotspot': [{'confidence': 97,
#               'latitude': -37.0155,
#               'longitude': 148.1432,
#               'surface_temperature_celsius': 80}]}
# {'_id': 123,
#  'hotspot': [{'confidence': 96,
#               'latitude': -37.8429,
#               'longitude': 147.2691,
#               'surface_temperature_celsius': 78},
#              {'confidence': 87,
#               'latitude': -38.0148,
#               'longitude': 146.5413,
#               'surface_temperature_celsius': 71},
#              {'confidence': 88,
#               'latitude': -38.0132,
#               'longitude': 146.5269,
#               'surface_temperature_celsius': 73},
#              {'confidence': 94,
#               'latitude': -36.2121,
#               'longitude': 144.6885,
#               'surface_temperature_celsius': 74},
#              {'confidence': 93,
#               'latitude': -37.5135,
#               'longitude': 142.7238,
#               'surface_temperature_celsius': 72},
#              {'confidence': 100,
#               'latitude': -36.664,
#               'longitude': 142.8802,
#               'surface_temperature_celsius': 87},
#              {'confidence': 99,
#               'latitude': -36.4286,
#               'longitude': 141.1567,
#               'surface_temperature_celsius': 84},
#              {'confidence': 91,
#               'latitude': -36.6564,
#               'longitude': 142.8615,
#               'surface_temperature_celsius': 69},
#              {'confidence': 100,
#               'latitude': -36.8791,
#               'longitude': 142.7261,
#               'surface_temperature_celsius': 93},
#              {'confidence': 91,
#               'latitude': -36.7751,
#               'longitude': 145.1696,
#               'surface_temperature_celsius': 68},
#              {'confidence': 91,
#               'latitude': -36.5061,
#               'longitude': 144.5675,
#               'surface_temperature_celsius': 68},
#              {'confidence': 100,
#               'latitude': -36.4035,
#               'longitude': 140.9935,
#               'surface_temperature_celsius': 95},
#              {'confidence': 98,
#               'latitude': -36.8742,
#               'longitude': 142.7177,
#               'surface_temperature_celsius': 84},
#              {'confidence': 97,
#               'latitude': -36.2206,
#               'longitude': 144.6856,
#               'surface_temperature_celsius': 80},
#              {'confidence': 91,
#               'latitude': -36.3635,
#               'longitude': 142.2809,
#               'surface_temperature_celsius': 68},
#              {'confidence': 100,
#               'latitude': -36.7742,
#               'longitude': 145.1991,
#               'surface_temperature_celsius': 89},
#              {'confidence': 92,
#               'latitude': -36.882,
#               'longitude': 142.7108,
#               'surface_temperature_celsius': 70},
#              {'confidence': 94,
#               'latitude': -37.6982,
#               'longitude': 143.0549,
#               'surface_temperature_celsius': 73},
#              {'confidence': 93,
#               'latitude': -36.6657,
#               'longitude': 143.1675,
#               'surface_temperature_celsius': 72},
#              {'confidence': 91,
#               'latitude': -36.3961,
#               'longitude': 140.9781,
#               'surface_temperature_celsius': 69},
#              {'confidence': 100,
#               'latitude': -37.8412,
#               'longitude': 147.2536,
#               'surface_temperature_celsius': 87},
#              {'confidence': 92,
#               'latitude': -36.803,
#               'longitude': 142.9261,
#               'surface_temperature_celsius': 70},
#              {'confidence': 95,
#               'latitude': -36.7187,
#               'longitude': 143.805,
#               'surface_temperature_celsius': 76},
#              {'confidence': 98,
#               'latitude': -37.758,
#               'longitude': 143.179,
#               'surface_temperature_celsius': 82},
#              {'confidence': 94,
#               'latitude': -37.7609,
#               'longitude': 143.1633,
#               'surface_temperature_celsius': 74},
#              {'confidence': 100,
#               'latitude': -36.7708,
#               'longitude': 145.1908,
#               'surface_temperature_celsius': 98},
#              {'confidence': 89,
#               'latitude': -36.5116,
#               'longitude': 144.562,
#               'surface_temperature_celsius': 66},
#              {'confidence': 92,
#               'latitude': -36.663,
#               'longitude': 142.8567,
#               'surface_temperature_celsius': 71},
#              {'confidence': 99,
#               'latitude': -36.7153,
#               'longitude': 143.8226,
#               'surface_temperature_celsius': 86},
#              {'confidence': 100,
#               'latitude': -36.7309,
#               'longitude': 142.3633,
#               'surface_temperature_celsius': 88}]}
# {'_id': 77,
#  'hotspot': [{'confidence': 90,
#               'latitude': -37.4523,
#               'longitude': 147.0175,
#               'surface_temperature_celsius': 66},
#              {'confidence': 96,
#               'latitude': -37.6622,
#               'longitude': 142.1001,
#               'surface_temperature_celsius': 79},
#              {'confidence': 98,
#               'latitude': -37.4261,
#               'longitude': 147.0323,
#               'surface_temperature_celsius': 83},
#              {'confidence': 92,
#               'latitude': -37.6625,
#               'longitude': 144.287,
#               'surface_temperature_celsius': 70},
#              {'confidence': 100,
#               'latitude': -37.3949,
#               'longitude': 147.0175,
#               'surface_temperature_celsius': 91}]}
# {'_id': 275,
#  'hotspot': [{'confidence': 100,
#               'latitude': -37.462,
#               'longitude': 148.089,
#               'surface_temperature_celsius': 90}]}
# {'_id': 124,
#  'hotspot': [{'confidence': 97,
#               'latitude': -36.6224,
#               'longitude': 143.5092,
#               'surface_temperature_celsius': 80},
#              {'confidence': 96,
#               'latitude': -38.0933,
#               'longitude': 143.9824,
#               'surface_temperature_celsius': 78},
#              {'confidence': 95,
#               'latitude': -37.9509,
#               'longitude': 143.9599,
#               'surface_temperature_celsius': 76},
#              {'confidence': 95,
#               'latitude': -36.6139,
#               'longitude': 143.501,
#               'surface_temperature_celsius': 77}]}
# {'_id': 107,
#  'hotspot': [{'confidence': 95,
#               'latitude': -36.738,
#               'longitude': 142.1177,
#               'surface_temperature_celsius': 77},
#              {'confidence': 92,
#               'latitude': -36.2652,
#               'longitude': 145.3769,
#               'surface_temperature_celsius': 70},
#              {'confidence': 93,
#               'latitude': -36.91,
#               'longitude': 141.0704,
#               'surface_temperature_celsius': 73},
#              {'confidence': 93,
#               'latitude': -36.4899,
#               'longitude': 142.2805,
#               'surface_temperature_celsius': 73},
#              {'confidence': 100,
#               'latitude': -35.8768,
#               'longitude': 145.4627,
#               'surface_temperature_celsius': 86},
#              {'confidence': 89,
#               'latitude': -37.2609,
#               'longitude': 141.7999,
#               'surface_temperature_celsius': 66},
#              {'confidence': 93,
#               'latitude': -36.8879,
#               'longitude': 141.6647,
#               'surface_temperature_celsius': 72},
#              {'confidence': 95,
#               'latitude': -36.6995,
#               'longitude': 142.978,
#               'surface_temperature_celsius': 76},
#              {'confidence': 96,
#               'latitude': -36.5987,
#               'longitude': 144.4995,
#               'surface_temperature_celsius': 79},
#              {'confidence': 100,
#               'latitude': -37.4352,
#               'longitude': 143.1444,
#               'surface_temperature_celsius': 96},
#              {'confidence': 92,
#               'latitude': -37.6498,
#               'longitude': 142.5997,
#               'surface_temperature_celsius': 70},
#              {'confidence': 94,
#               'latitude': -37.7236,
#               'longitude': 142.947,
#               'surface_temperature_celsius': 73},
#              {'confidence': 91,
#               'latitude': -37.7171,
#               'longitude': 142.9505,
#               'surface_temperature_celsius': 68},
#              {'confidence': 96,
#               'latitude': -37.7935,
#               'longitude': 143.1606,
#               'surface_temperature_celsius': 78},
#              {'confidence': 97,
#               'latitude': -37.4885,
#               'longitude': 142.0658,
#               'surface_temperature_celsius': 81},
#              {'confidence': 90,
#               'latitude': -36.7101,
# ...
#               'surface_temperature_celsius': 68},
#              {'confidence': 71,
#               'latitude': -37.522,
#               'longitude': 143.3874,
#               'surface_temperature_celsius': 73}]}
# {'_id': 134,
#  'hotspot': [{'confidence': 100,
#               'latitude': -38.0361,
#               'longitude': 146.0567,
#               'surface_temperature_celsius': 90},
#              {'confidence': 95,
#               'latitude': -36.0396,
#               'longitude': 141.7183,
#               'surface_temperature_celsius': 76},
#              {'confidence': 94,
#               'latitude': -38.049,
#               'longitude': 146.0513,
#               'surface_temperature_celsius': 74},
#              {'confidence': 90,
#               'latitude': -38.0372,
#               'longitude': 146.0616,
#               'surface_temperature_celsius': 67},
#              {'confidence': 92,
#               'latitude': -36.9396,
#               'longitude': 143.1462,
#               'surface_temperature_celsius': 70},
#              {'confidence': 96,
#               'latitude': -37.253,
#               'longitude': 144.3681,
#               'surface_temperature_celsius': 78},
#              {'confidence': 96,
#               'latitude': -36.3387,
#               'longitude': 141.7542,
#               'surface_temperature_celsius': 77},
#              {'confidence': 90,
#               'latitude': -36.7032,
#               'longitude': 144.0992,
#               'surface_temperature_celsius': 66},
#              {'confidence': 93,
#               'latitude': -37.4984,
#               'longitude': 142.9739,
#               'surface_temperature_celsius': 73},
#              {'confidence': 90,
#               'latitude': -36.8616,
#               'longitude': 142.8025,
#               'surface_temperature_celsius': 78},
#              {'confidence': 100,
#               'latitude': -36.3433,
#               'longitude': 143.4369,
#               'surface_temperature_celsius': 94},
#              {'confidence': 100,
#               'latitude': -36.345,
#               'longitude': 143.4256,
#               'surface_temperature_celsius': 87},
#              {'confidence': 94,
#               'latitude': -36.2775,
#               'longitude': 146.1026,
#               'surface_temperature_celsius': 74},
#              {'confidence': 96,
#               'latitude': -36.3402,
#               'longitude': 141.7429,
#               'surface_temperature_celsius': 77},
#              {'confidence': 85,
#               'latitude': -36.5023,
#               'longitude': 143.6038,
#               'surface_temperature_celsius': 66}]}
# {'_id': 108,
#  'hotspot': [{'confidence': 93,
#               'latitude': -36.1964,
#               'longitude': 144.5217,
#               'surface_temperature_celsius': 72},
#              {'confidence': 100,
#               'latitude': -37.5043,
#               'longitude': 146.3299,
#               'surface_temperature_celsius': 93},
#              {'confidence': 100,
#               'latitude': -37.5027,
#               'longitude': 146.347,
#               'surface_temperature_celsius': 95},
#              {'confidence': 100,
#               'latitude': -37.3902,
#               'longitude': 148.2955,
#               'surface_temperature_celsius': 98},
#              {'confidence': 88,
#               'latitude': -36.1546,
#               'longitude': 141.8146,
#               'surface_temperature_celsius': 74},
#              {'confidence': 87,
#               'latitude': -37.9091,
#               'longitude': 143.5105,
#               'surface_temperature_celsius': 70},
#              {'confidence': 80,
#               'latitude': -36.1559,
#               'longitude': 141.8102,
#               'surface_temperature_celsius': 66},
#              {'confidence': 100,
#               'latitude': -37.9071,
#               'longitude': 143.538,
#               'surface_temperature_celsius': 88}]}
# {'_id': 312,
#  'hotspot': [{'confidence': 96,
#               'latitude': -37.475,
#               'longitude': 143.365,
#               'surface_temperature_celsius': 77},
#              {'confidence': 97,
#               'latitude': -37.69,
#               'longitude': 143.605,
#               'surface_temperature_celsius': 80},
#              {'confidence': 100,
#               'latitude': -37.477,
#               'longitude': 143.352,
#               'surface_temperature_celsius': 93}]}
# {'_id': 109,
#  'hotspot': [{'confidence': 96,
#               'latitude': -36.5847,
#               'longitude': 145.1968,
#               'surface_temperature_celsius': 78},
#              {'confidence': 93,
#               'latitude': -37.769,
#               'longitude': 147.94,
#               'surface_temperature_celsius': 72},
#              {'confidence': 98,
#               'latitude': -36.1345,
#               'longitude': 146.351,
#               'surface_temperature_celsius': 84},
#              {'confidence': 90,
#               'latitude': -36.1303,
#               'longitude': 146.3606,
#               'surface_temperature_celsius': 67},
#              {'confidence': 99,
#               'latitude': -36.1586,
#               'longitude': 145.6666,
#               'surface_temperature_celsius': 85}]}
# {'_id': 112,
#  'hotspot': [{'confidence': 99,
#               'latitude': -37.5115,
#               'longitude': 143.14,
#               'surface_temperature_celsius': 86},
#              {'confidence': 93,
#               'latitude': -36.9111,
#               'longitude': 142.692,
#               'surface_temperature_celsius': 72}]}
# {'_id': 113,
#  'hotspot': [{'confidence': 86,
#               'latitude': -37.6775,
#               'longitude': 148.5131,
#               'surface_temperature_celsius': 78}]}
# {'_id': 118,
#  'hotspot': [{'confidence': 87,
#               'latitude': -36.3332,
#               'longitude': 145.8594,
#               'surface_temperature_celsius': 90}]}
# {'_id': 120,
#  'hotspot': [{'confidence': 95,
#               'latitude': -36.3014,
#               'longitude': 143.203,
#               'surface_temperature_celsius': 76},
#              {'confidence': 70,
#               'latitude': -36.9303,
#               'longitude': 143.1034,
#               'surface_temperature_celsius': 72},
#              {'confidence': 100,
#               'latitude': -36.5839,
#               'longitude': 143.0588,
#               'surface_temperature_celsius': 99},
#              {'confidence': 83,
#               'latitude': -36.3195,
#               'longitude': 146.0601,
#               'surface_temperature_celsius': 77},
#              {'confidence': 100,
#               'latitude': -36.5854,
#               'longitude': 143.0462,
#               'surface_temperature_celsius': 94}]}
# {'_id': 360,
#  'hotspot': [{'confidence': 86,
#               'latitude': -35.543,
#               'longitude': 143.316,
#               'surface_temperature_celsius': 67},
#              {'confidence': 78,
#               'latitude': -37.966,
#               'longitude': 145.051,
#               'surface_temperature_celsius': 68}]}
# {'_id': 121,
#  'hotspot': [{'confidence': 95,
#               'latitude': -38.1987,
#               'longitude': 147.0666,
#               'surface_temperature_celsius': 76},
#              {'confidence': 100,
#               'latitude': -38.1917,
#               'longitude': 147.0745,
#               'surface_temperature_celsius': 94}]}
# {'_id': 125,
#  'hotspot': [{'confidence': 92,
#               'latitude': -37.7889,
#               'longitude': 143.1324,
#               'surface_temperature_celsius': 71},
#              {'confidence': 100,
#               'latitude': -36.0682,
#               'longitude': 146.0602,
#               'surface_temperature_celsius': 90},
#              {'confidence': 91,
#               'latitude': -35.6138,
#               'longitude': 143.8666,
#               'surface_temperature_celsius': 68},
#              {'confidence': 95,
#               'latitude': -36.0885,
#               'longitude': 145.0359,
#               'surface_temperature_celsius': 76},
#              {'confidence': 96,
#               'latitude': -36.3193,
#               'longitude': 145.9162,
#               'surface_temperature_celsius': 78},
#              {'confidence': 98,
#               'latitude': -36.0652,
#               'longitude': 146.0764,
#               'surface_temperature_celsius': 82}]}
# {'_id': 287,
#  'hotspot': [{'confidence': 99,
#               'latitude': -37.293,
#               'longitude': 141.245,
#               'surface_temperature_celsius': 85},
#              {'confidence': 100,
#               'latitude': -37.294,
#               'longitude': 141.232,
#               'surface_temperature_celsius': 87}]}
# {'_id': 127,
#  'hotspot': [{'confidence': 97,
#               'latitude': -36.4211,
#               'longitude': 141.6875,
#               'surface_temperature_celsius': 81},
#              {'confidence': 91,
#               'latitude': -36.4168,
#               'longitude': 141.6939,
#               'surface_temperature_celsius': 68},
#              {'confidence': 93,
#               'latitude': -36.2306,
#               'longitude': 143.6408,
#               'surface_temperature_celsius': 72}]}
# {'_id': 130,
#  'hotspot': [{'confidence': 97,
#               'latitude': -36.4169,
#               'longitude': 144.2994,
#               'surface_temperature_celsius': 81},
#              {'confidence': 91,
#               'latitude': -36.3153,
#               'longitude': 140.9789,
#               'surface_temperature_celsius': 69},
#              {'confidence': 90,
#               'latitude': -36.2911,
#               'longitude': 141.1664,
#               'surface_temperature_celsius': 67},
#              {'confidence': 99,
#               'latitude': -36.2882,
#               'longitude': 141.1821,
#               'surface_temperature_celsius': 86},
#              {'confidence': 92,
#               'latitude': -36.3207,
#               'longitude': 140.9737,
#               'surface_temperature_celsius': 70},
#              {'confidence': 96,
#               'latitude': -36.2842,
#               'longitude': 141.1741,
#               'surface_temperature_celsius': 79},
#              {'confidence': 84,
#               'latitude': -37.3656,
#               'longitude': 141.3903,
#               'surface_temperature_celsius': 78},
#              {'confidence': 94,
#               'latitude': -36.4179,
#               'longitude': 144.2924,
#               'surface_temperature_celsius': 75}]}
# {'_id': 86,
#  'hotspot': [{'confidence': 94,
#               'latitude': -36.7806,
#               'longitude': 141.5597,
#               'surface_temperature_celsius': 74},
#              {'confidence': 93,
#               'latitude': -36.8099,
#               'longitude': 142.728,
#               'surface_temperature_celsius': 73},
#              {'confidence': 95,
#               'latitude': -36.8009,
#               'longitude': 142.7259,
#               'surface_temperature_celsius': 76},
#              {'confidence': 92,
#               'latitude': -36.4557,
#               'longitude': 142.2434,
#               'surface_temperature_celsius': 71},
#              {'confidence': 98,
#               'latitude': -34.3526,
#               'longitude': 141.6458,
#               'surface_temperature_celsius': 82},
#              {'confidence': 100,
#               'latitude': -37.5012,
#               'longitude': 142.5853,
#               'surface_temperature_celsius': 90},
#              {'confidence': 97,
#               'latitude': -37.9452,
#               'longitude': 143.5834,
#               'surface_temperature_celsius': 80},
#              {'confidence': 97,
#               'latitude': -35.0805,
#               'longitude': 142.4642,
#               'surface_temperature_celsius': 81},
#              {'confidence': 99,
#               'latitude': -34.351,
#               'longitude': 141.6567,
#               'surface_temperature_celsius': 86},
#              {'confidence': 97,
#               'latitude': -37.0924,
#               'longitude': 141.897,
#               'surface_temperature_celsius': 80},
#              {'confidence': 97,
#               'latitude': -37.9247,
#               'longitude': 142.8999,
#               'surface_temperature_celsius': 81}]}
# {'_id': 141,
#  'hotspot': [{'confidence': 100,
#               'latitude': -37.9047,
#               'longitude': 141.0945,
#               'surface_temperature_celsius': 90},
#              {'confidence': 91,
#               'latitude': -36.7746,
#               'longitude': 146.6642,
#               'surface_temperature_celsius': 68},
#              {'confidence': 96,
#               'latitude': -36.8359,
#               'longitude': 146.6448,
#               'surface_temperature_celsius': 78},
#              {'confidence': 98,
#               'latitude': -37.9085,
#               'longitude': 141.1038,
#               'surface_temperature_celsius': 82},
#              {'confidence': 100,
#               'latitude': -38.4349,
#               'longitude': 146.3122,
#               'surface_temperature_celsius': 93}]}
# {'_id': 266,
#  'hotspot': [{'confidence': 61,
#               'latitude': -37.562,
#               'longitude': 148.05,
#               'surface_temperature_celsius': 72},
#              {'confidence': 73,
#               'latitude': -37.444,
#               'longitude': 148.101,
#               'surface_temperature_celsius': 66},
#              {'confidence': 100,
#               'latitude': -37.406,
#               'longitude': 148.123,
#               'surface_temperature_celsius': 88},
#              {'confidence': 68,
#               'latitude': -37.452,
#               'longitude': 148.115,
#               'surface_temperature_celsius': 77},
#              {'confidence': 64,
#               'latitude': -37.45,
#               'longitude': 148.126,
#               'surface_temperature_celsius': 69},
#              {'confidence': 86,
#               'latitude': -37.436,
#               'longitude': 148.088,
#               'surface_temperature_celsius': 76}]}
# {'_id': 164,
#  'hotspot': [{'confidence': 94,
#               'latitude': -36.2693,
#               'longitude': 143.1768,
#               'surface_temperature_celsius': 85}]}
# {'_id': 186,
#  'hotspot': [{'confidence': 91,
#               'latitude': -37.8644,
#               'longitude': 143.4263,
#               'surface_temperature_celsius': 69}]}
# {'_id': 122,
#  'hotspot': [{'confidence': 95,
#               'latitude': -36.6537,
#               'longitude': 143.8781,
#               'surface_temperature_celsius': 76},
#              {'confidence': 99,
#               'latitude': -36.5438,
#               'longitude': 144.7548,
#               'surface_temperature_celsius': 84},
#              {'confidence': 93,
#               'latitude': -36.6942,
#               'longitude': 143.8021,
#               'surface_temperature_celsius': 72},
#              {'confidence': 90,
#               'latitude': -36.3435,
#               'longitude': 141.5513,
#               'surface_temperature_celsius': 67},
#              {'confidence': 100,
#               'latitude': -36.3459,
#               'longitude': 141.5586,
#               'surface_temperature_celsius': 91},
#              {'confidence': 93,
#               'latitude': -36.4046,
#               'longitude': 141.1534,
#               'surface_temperature_celsius': 73},
#              {'confidence': 93,
#               'latitude': -36.388,
#               'longitude': 141.8309,
#               'surface_temperature_celsius': 73},
#              {'confidence': 100,
#               'latitude': -36.5454,
#               'longitude': 144.7402,
#               'surface_temperature_celsius': 96},
#              {'confidence': 92,
#               'latitude': -36.7593,
#               'longitude': 142.895,
#               'surface_temperature_celsius': 69},
#              {'confidence': 90,
#               'latitude': -36.094,
#               'longitude': 145.7646,
#               'surface_temperature_celsius': 67},
#              {'confidence': 96,
#               'latitude': -36.0594,
#               'longitude': 141.5907,
#               'surface_temperature_celsius': 79},
#              {'confidence': 100,
#               'latitude': -36.0576,
#               'longitude': 141.6122,
#               'surface_temperature_celsius': 94}]}
# {'_id': 213,
#  'hotspot': [{'confidence': 94,
#               'latitude': -37.4796,
#               'longitude': 141.9403,
#               'surface_temperature_celsius': 87}]}

# %% [markdown]
# ## 10. (2C) Find Dates, Surface Temperatures, Air Temperatures, Relative Humidities, and Max Wind Speeds from the 15th and 16 of December, 2017

# %%
# Return documents where `date` is either '15/12/2017' or '16/12/2017' and `hotspot` is not an empty list
for i in db.climate.find({'hotspot': {'$not': {'$size': 0}},
                          '$or': [{'date': '15/12/2017'}, {'date': '16/12/2017'}]},
                         {'date': 1,
                          'climate.air_temperature_celsius': 1, 
                          'climate.max_wind_speed': 1,                           
                          'climate.relative_humidity': 1, 
                          'hotspot.surface_temperature_celsius': 1, 
                          '_id': 1}):
    pprint(i)
# Out:
# {'_id': 348,
#  'climate': {'air_temperature_celsius': 18,
#              'max_wind_speed': 14.0,
#              'relative_humidity': 52.0},
#  'date': '15/12/2017',
#  'hotspot': [{'surface_temperature_celsius': 42},
#              {'surface_temperature_celsius': 36},
#              {'surface_temperature_celsius': 38},
#              {'surface_temperature_celsius': 40}]}
# {'_id': 349,
#  'climate': {'air_temperature_celsius': 18,
#              'max_wind_speed': 13.0,
#              'relative_humidity': 53.7},
#  'date': '16/12/2017',
#  'hotspot': [{'surface_temperature_celsius': 43},
#              {'surface_temperature_celsius': 33},
#              {'surface_temperature_celsius': 54},
#              {'surface_temperature_celsius': 73},
#              {'surface_temperature_celsius': 55},
#              {'surface_temperature_celsius': 75},
#              {'surface_temperature_celsius': 55},
#              {'surface_temperature_celsius': 66},
#              {'surface_temperature_celsius': 56},
#              {'surface_temperature_celsius': 60},
#              {'surface_temperature_celsius': 73},
#              {'surface_temperature_celsius': 48},
#              {'surface_temperature_celsius': 55},
#              {'surface_temperature_celsius': 64},
#              {'surface_temperature_celsius': 57}]}

# %% [markdown]
# ## 11. (2D) Find Datetimes, Air Temperatures, Surface Temperatures, and Confidences Where Confidence Is Between 80 and 90

# %%
for i in db.climate.aggregate([
    {'$match': {'hotspot.confidence': {'$gt': 80, '$lt': 90}}},
    {'$unwind': '$hotspot'},
    {'$unwind': '$hotspot.confidence'},
    {'$match': {'hotspot.confidence': {'$gt': 80, '$lt': 90}}},
    {'$group': {
        '_id': '$_id',
        'air_temperature_celsius': {'$addToSet': '$climate.air_temperature_celsius'},
        'hotspot': {'$addToSet': '$hotspot'}
    }},
    {'$unwind': '$air_temperature_celsius'},
    {'$project': {
        'air_temperature_celsius': 1,
        'hotspot.confidence': 1,
        'hotspot.datetime': 1,
        'hotspot.surface_temperature_celsius': 1,`
        '_id': 1        
    }}
]):
    pprint(i)
# Out:
# {'_id': 346,
#  'air_temperature_celsius': 28,
#  'hotspot': [{'confidence': 83,
#               'datetime': '2017-12-13T04:04:19',
#               'surface_temperature_celsius': 60}]}
# {'_id': 333,
#  'air_temperature_celsius': 26,
#  'hotspot': [{'confidence': 87,
#               'datetime': '2017-11-30T00:20:53',
#               'surface_temperature_celsius': 63},
#              {'confidence': 81,
#               'datetime': '2017-11-30T00:20:53',
#               'surface_temperature_celsius': 56},
#              {'confidence': 83,
#               'datetime': '2017-11-30T00:20:53',
#               'surface_temperature_celsius': 58},
#              {'confidence': 81,
#               'datetime': '2017-11-30T00:20:53',
#               'surface_temperature_celsius': 55},
#              {'confidence': 84,
#               'datetime': '2017-11-30T04:34:57',
#               'surface_temperature_celsius': 61},
#              {'confidence': 84,
#               'datetime': '2017-11-30T12:22:15',
#               'surface_temperature_celsius': 38},
#              {'confidence': 81,
#               'datetime': '2017-11-30T12:22:15',
#               'surface_temperature_celsius': 42},
#              {'confidence': 84,
#               'datetime': '2017-11-30T04:35:00',
#               'surface_temperature_celsius': 59},
#              {'confidence': 81,
#               'datetime': '2017-11-30T04:34:57',
#               'surface_temperature_celsius': 57}]}
# {'_id': 316,
#  'air_temperature_celsius': 24,
#  'hotspot': [{'confidence': 81,
#               'datetime': '2017-11-13T03:52:14',
#               'surface_temperature_celsius': 53},
#              {'confidence': 87,
#               'datetime': '2017-11-13T03:52:15',
#               'surface_temperature_celsius': 61}]}
# {'_id': 315,
#  'air_temperature_celsius': 18,
#  'hotspot': [{'confidence': 89,
#               'datetime': '2017-11-12T00:33:15',
#               'surface_temperature_celsius': 69}]}
# {'_id': 314,
#  'air_temperature_celsius': 18,
#  'hotspot': [{'confidence': 86,
#               'datetime': '2017-11-11T04:04:25',
#               'surface_temperature_celsius': 60}]}
# {'_id': 290,
#  'air_temperature_celsius': 26,
#  'hotspot': [{'confidence': 82,
#               'datetime': '2017-10-18T00:39:02',
#               'surface_temperature_celsius': 56},
#              {'confidence': 84,
#               'datetime': '2017-10-18T00:39:02',
#               'surface_temperature_celsius': 59}]}
# {'_id': 274,
#  'air_temperature_celsius': 11,
#  'hotspot': [{'confidence': 85,
#               'datetime': '2017-10-02T04:53:09',
#               'surface_temperature_celsius': 61},
#              {'confidence': 83,
#               'datetime': '2017-10-02T04:53:10',
#               'surface_temperature_celsius': 50}]}
# {'_id': 269,
#  'air_temperature_celsius': 15,
#  'hotspot': [{'confidence': 86,
#               'datetime': '2017-09-27T04:35:36',
#               'surface_temperature_celsius': 60},
#              {'confidence': 83,
#               'datetime': '2017-09-27T04:35:36',
#               'surface_temperature_celsius': 56}]}
# {'_id': 266,
#  'air_temperature_celsius': 14,
#  'hotspot': [{'confidence': 84,
#               'datetime': '2017-09-24T04:04:04',
#               'surface_temperature_celsius': 52},
#              {'confidence': 86,
#               'datetime': '2017-09-24T04:04:18',
#               'surface_temperature_celsius': 76},
#              {'confidence': 84,
#               'datetime': '2017-09-24T13:30:07',
#               'surface_temperature_celsius': 50},
#              {'confidence': 82,
#               'datetime': '2017-09-24T13:30:09',
#               'surface_temperature_celsius': 38}]}
# {'_id': 262,
#  'air_temperature_celsius': 14,
#  'hotspot': [{'confidence': 88,
#               'datetime': '2017-09-20T04:28:45',
#               'surface_temperature_celsius': 60},
#              {'confidence': 89,
#               'datetime': '2017-09-20T04:29:03',
#               'surface_temperature_celsius': 60}]}
# {'_id': 289,
#  'air_temperature_celsius': 22,
#  'hotspot': [{'confidence': 82,
#               'datetime': '2017-10-17T04:10:32',
#               'surface_temperature_celsius': 55}]}
# {'_id': 224,
#  'air_temperature_celsius': 15,
#  'hotspot': [{'confidence': 83,
#               'datetime': '2017-08-13T05:02:30',
#               'surface_temperature_celsius': 56},
#              {'confidence': 87,
#               'datetime': '2017-08-13T05:08:00',
#               'surface_temperature_celsius': 62}]}
# {'_id': 265,
#  'air_temperature_celsius': 17,
#  'hotspot': [{'confidence': 87,
#               'datetime': '2017-09-23T04:59:11',
#               'surface_temperature_celsius': 60},
#              {'confidence': 88,
#               'datetime': '2017-09-23T04:59:13',
#               'surface_temperature_celsius': 60},
#              {'confidence': 86,
#               'datetime': '2017-09-23T23:50:44',
#               'surface_temperature_celsius': 56}]}
# {'_id': 212,
#  'air_temperature_celsius': 7,
#  'hotspot': [{'confidence': 89,
#               'datetime': '2017-08-01T00:20:30',
#               'surface_temperature_celsius': 65}]}
# {'_id': 186,
#  'air_temperature_celsius': 9,
#  'hotspot': [{'confidence': 83,
#               'datetime': '2017-07-06T04:08:00',
#               'surface_temperature_celsius': 56}]}
# {'_id': 182,
#  'air_temperature_celsius': 6,
#  'hotspot': [{'confidence': 88,
#               'datetime': '2017-07-02T04:29:00',
#               'surface_temperature_celsius': 58},
#              {'confidence': 84,
#               'datetime': '2017-07-02T04:29:18',
#               'surface_temperature_celsius': 52}]}
# {'_id': 180,
#  'air_temperature_celsius': 5,
#  'hotspot': [{'confidence': 81,
#               'datetime': '2017-06-30T00:27:19',
#               'surface_temperature_celsius': 48}]}
# {'_id': 154,
#  'air_temperature_celsius': 9,
#  'hotspot': [{'confidence': 85,
#               'datetime': '2017-06-04T04:02:10',
#               'surface_temperature_celsius': 59},
#              {'confidence': 86,
#               'datetime': '2017-06-04T04:08:20',
#               'surface_temperature_celsius': 61}]}
# {'_id': 152,
#  'air_temperature_celsius': 12,
#  'hotspot': [{'confidence': 83,
#               'datetime': '2017-06-02T04:14:10',
#               'surface_temperature_celsius': 57},
#              {'confidence': 83,
#               'datetime': '2017-06-02T04:14:10',
#               'surface_temperature_celsius': 57}]}
# {'_id': 151,
#  'air_temperature_celsius': 11,
#  'hotspot': [{'confidence': 82,
#               'datetime': '2017-06-01T05:09:20',
#               'surface_temperature_celsius': 56}]}
# {'_id': 325,
#  'air_temperature_celsius': 23,
#  'hotspot': [{'confidence': 88,
#               'datetime': '2017-11-22T03:46:00',
#               'surface_temperature_celsius': 64},
#              {'confidence': 84,
#               'datetime': '2017-11-22T03:46:00',
#               'surface_temperature_celsius': 59}]}
# {'_id': 145,
#  'air_temperature_celsius': 13,
#  'hotspot': [{'confidence': 85,
#               'datetime': '2017-05-26T04:08:10',
#               'surface_temperature_celsius': 59}]}
# {'_id': 142,
#  'air_temperature_celsius': 15,
#  'hotspot': [{'confidence': 81,
#               'datetime': '2017-05-23T00:54:50',
#               'surface_temperature_celsius': 55},
#              {'confidence': 84,
#               'datetime': '2017-05-23T00:58:00',
#               'surface_temperature_celsius': 59}]}
# {'_id': 292,
#  'air_temperature_celsius': 13,
#  'hotspot': [{'confidence': 82,
#               'datetime': '2017-10-20T04:41:19',
#               'surface_temperature_celsius': 50}]}
# {'_id': 104,
#  'air_temperature_celsius': 12,
#  'hotspot': [{'confidence': 87,
#               'datetime': '2017-04-15T04:14:20',
#               'surface_temperature_celsius': 61},
#              {'confidence': 82,
#               'datetime': '2017-04-15T04:14:20',
#               'surface_temperature_celsius': 55},
#              {'confidence': 81,
#               'datetime': '2017-04-15T04:14:20',
#               'surface_temperature_celsius': 55},
#              {'confidence': 82,
#               'datetime': '2017-04-15T04:14:20',
#               'surface_temperature_celsius': 55},
#              {'confidence': 81,
#               'datetime': '2017-04-15T04:14:50',
#               'surface_temperature_celsius': 54},
#              {'confidence': 82,
#               'datetime': '2017-04-15T04:16:00',
#               'surface_temperature_celsius': 55},
#              {'confidence': 82,
#               'datetime': '2017-04-15T04:15:40',
#               'surface_temperature_celsius': 56},
#              {'confidence': 84,
#               'datetime': '2017-04-15T04:15:10',
#               'surface_temperature_celsius': 58},
#              {'confidence': 86,
#               'datetime': '2017-04-15T04:15:10',
#               'surface_temperature_celsius': 61},
#              {'confidence': 89,
#               'datetime': '2017-04-15T04:15:10',
#               'surface_temperature_celsius': 65},
#              {'confidence': 87,
#               'datetime': '2017-04-15T04:17:30',
#               'surface_temperature_celsius': 61},
#              {'confidence': 81,
#               'datetime': '2017-04-15T04:16:00',
#               'surface_temperature_celsius': 55},
#              {'confidence': 82,
#               'datetime': '2017-04-15T04:15:10',
#               'surface_temperature_celsius': 55},
#              {'confidence': 88,
#               'datetime': '2017-04-15T04:15:10',
#               'surface_temperature_celsius': 63},
#              {'confidence': 81,
#               'datetime': '2017-04-15T04:15:00',
#               'surface_temperature_celsius': 54}]}
# {'_id': 103,
#  'air_temperature_celsius': 13,
#  'hotspot': [{'confidence': 87,
#               'datetime': '2017-04-14T03:33:00',
#               'surface_temperature_celsius': 63},
#              {'confidence': 86,
#               'datetime': '2017-04-14T03:35:20',
#               'surface_temperature_celsius': 61},
#              {'confidence': 82,
#               'datetime': '2017-04-14T05:15:50',
#               'surface_temperature_celsius': 55},
#              {'confidence': 87,
#               'datetime': '2017-04-14T05:09:10',
#               'surface_temperature_celsius': 62},
#              {'confidence': 84,
#               'datetime': '2017-04-14T05:09:10',
#               'surface_temperature_celsius': 79},
#              {'confidence': 84,
#               'datetime': '2017-04-14T05:09:10',
#               'surface_temperature_celsius': 78}]}
# {'_id': 102,
#  'air_temperature_celsius': 16,
#  'hotspot': [{'confidence': 82,
#               'datetime': '2017-04-13T00:07:40',
#               'surface_temperature_celsius': 55},
#              {'confidence': 82,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 55},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 55},
#              {'confidence': 88,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 64},
#              {'confidence': 83,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 56},
#              {'confidence': 87,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 63},
#              {'confidence': 83,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 56},
#              {'confidence': 84,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 58},
#              {'confidence': 84,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 58},
#              {'confidence': 83,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 57},
#              {'confidence': 89,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 65},
#              {'confidence': 88,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 63},
#              {'confidence': 83,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 57},
#              {'confidence': 84,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 80},
#              {'confidence': 86,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 61},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 54},
#              {'confidence': 85,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 59},
#              {'confidence': 83,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 57},
#              {'confidence': 83,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 56},
#              {'confidence': 85,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 59},
#              {'confidence': 88,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 64},
#              {'confidence': 84,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 58},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:28:10',
#               'surface_temperature_celsius': 55},
#              {'confidence': 86,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 61},
#              {'confidence': 84,
#               'datetime': '2017-04-13T04:28:30',
#               'surface_temperature_celsius': 58},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:29:40',
#               'surface_temperature_celsius': 54},
#              {'confidence': 89,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 65},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:29:50',
#               'surface_temperature_celsius': 55},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:34:40',
#               'surface_temperature_celsius': 54},
#              {'confidence': 88,
#               'datetime': '2017-04-13T04:29:40',
#               'surface_temperature_celsius': 64},
#              {'confidence': 89,
#               'datetime': '2017-04-13T04:30:50',
#               'surface_temperature_celsius': 65},
#              {'confidence': 82,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 56},
#              {'confidence': 84,
#               'datetime': '2017-04-13T04:33:40',
#               'surface_temperature_celsius': 58},
#              {'confidence': 84,
#               'datetime': '2017-04-13T04:26:50',
#               'surface_temperature_celsius': 58},
#              {'confidence': 86,
#               'datetime': '2017-04-13T04:35:30',
#               'surface_temperature_celsius': 60},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 55},
#              {'confidence': 82,
#               'datetime': '2017-04-13T04:33:00',
#               'surface_temperature_celsius': 55},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 54},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:27:20',
#               'surface_temperature_celsius': 54},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 54},
#              {'confidence': 84,
#               'datetime': '2017-04-13T04:28:10',
#               'surface_temperature_celsius': 58},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 54},
#              {'confidence': 89,
#               'datetime': '2017-04-13T04:28:50',
#               'surface_temperature_celsius': 65},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:33:40',
#               'surface_temperature_celsius': 54},
#              {'confidence': 89,
#               'datetime': '2017-04-13T04:36:20',
#               'surface_temperature_celsius': 65},
#              {'confidence': 84,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 58},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:28:10',
#               'surface_temperature_celsius': 54},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 54},
#              {'confidence': 89,
#               'datetime': '2017-04-13T04:35:40',
#               'surface_temperature_celsius': 64},
#              {'confidence': 85,
#               'datetime': '2017-04-13T04:35:40',
#               'surface_temperature_celsius': 59},
#              {'confidence': 86,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 61},
#              {'confidence': 86,
#               'datetime': '2017-04-13T04:36:50',
#               'surface_temperature_celsius': 60},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 54},
#              {'confidence': 89,
#               'datetime': '2017-04-13T04:33:20',
#               'surface_temperature_celsius': 66},
#              {'confidence': 86,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 60},
#              {'confidence': 88,
#               'datetime': '2017-04-13T04:33:00',
#               'surface_temperature_celsius': 63},
#              {'confidence': 86,
#               'datetime': '2017-04-13T04:27:20',
#               'surface_temperature_celsius': 60},
#              {'confidence': 89,
#               'datetime': '2017-04-13T04:30:50',
#               'surface_temperature_celsius': 64},
#              {'confidence': 88,
#               'datetime': '2017-04-13T04:27:20',
#               'surface_temperature_celsius': 64},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:27:20',
#               'surface_temperature_celsius': 55},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 55},
#              {'confidence': 85,
#               'datetime': '2017-04-13T04:26:50',
#               'surface_temperature_celsius': 59},
#              {'confidence': 86,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 61},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 55},
#              {'confidence': 83,
#               'datetime': '2017-04-13T04:26:40',
#               'surface_temperature_celsius': 57},
#              {'confidence': 85,
#               'datetime': '2017-04-13T04:26:40',
#               'surface_temperature_celsius': 60},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 54},
#              {'confidence': 86,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 61},
#              {'confidence': 85,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 59},
#              {'confidence': 86,
#               'datetime': '2017-04-13T04:30:00',
#               'surface_temperature_celsius': 61},
#              {'confidence': 84,
#               'datetime': '2017-04-13T04:26:40',
#               'surface_temperature_celsius': 58},
#              {'confidence': 86,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 60},
#              {'confidence': 81,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 55},
#              {'confidence': 86,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 60},
#              {'confidence': 86,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 61},
#              {'confidence': 84,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 58},
#              {'confidence': 87,
#               'datetime': '2017-04-13T04:26:30',
#               'surface_temperature_celsius': 61}]}
# {'_id': 101,
#  'air_temperature_celsius': 14,
#  'hotspot': [{'confidence': 82,
#               'datetime': '2017-04-12T03:44:40',
#               'surface_temperature_celsius': 55},
#              {'confidence': 85,
#               'datetime': '2017-04-12T03:45:10',
#               'surface_temperature_celsius': 59},
#              {'confidence': 84,
#               'datetime': '2017-04-12T03:47:20',
#               'surface_temperature_celsius': 57},
#              {'confidence': 84,
#               'datetime': '2017-04-12T03:47:30',
#               'surface_temperature_celsius': 58},
#              {'confidence': 87,
#               'datetime': '2017-04-12T03:44:40',
#               'surface_temperature_celsius': 63},
#              {'confidence': 84,
#               'datetime': '2017-04-12T05:28:00',
#               'surface_temperature_celsius': 58},
#              {'confidence': 83,
#               'datetime': '2017-04-12T03:47:20',
#               'surface_temperature_celsius': 56},
#              {'confidence': 87,
#               'datetime': '2017-04-12T03:50:00',
#               'surface_temperature_celsius': 63},
#              {'confidence': 86,
#               'datetime': '2017-04-12T03:50:00',
#               'surface_temperature_celsius': 61},
#              {'confidence': 84,
#               'datetime': '2017-04-12T03:47:50',
#               'surface_temperature_celsius': 58}]}
# {'_id': 96,
#  'air_temperature_celsius': 21,
#  'hotspot': [{'confidence': 81,
#               'datetime': '2017-04-07T05:03:10',
#               'surface_temperature_celsius': 54},
#              {'confidence': 85,
#               'datetime': '2017-04-07T12:56:50',
#               'surface_temperature_celsius': 41},
#              {'confidence': 89,
#               'datetime': '2017-04-07T12:50:40',
#               'surface_temperature_celsius': 42},
#              {'confidence': 86,
#               'datetime': '2017-04-07T12:53:40',
#               'surface_temperature_celsius': 41},
#              {'confidence': 86,
#               'datetime': '2017-04-07T12:52:10',
#               'surface_temperature_celsius': 41}]}
# {'_id': 349,
#  'air_temperature_celsius': 18,
#  'hotspot': [{'confidence': 82,
#               'datetime': '2017-12-16T00:20:53',
#               'surface_temperature_celsius': 64},
#              {'confidence': 82,
#               'datetime': '2017-12-16T00:21:11',
#               'surface_temperature_celsius': 55},
#              {'confidence': 84,
#               'datetime': '2017-12-16T04:34:58',
#               'surface_temperature_celsius': 55}]}
# {'_id': 157,
#  'air_temperature_celsius': 8,
#  'hotspot': [{'confidence': 85,
#               'datetime': '2017-06-07T04:32:10',
#               'surface_temperature_celsius': 59},
#              {'confidence': 81,
#               'datetime': '2017-06-07T04:32:10',
#               'surface_temperature_celsius': 54},
#              {'confidence': 85,
#               'datetime': '2017-06-07T04:32:10',
#               'surface_temperature_celsius': 59},
#              {'confidence': 86,
#               'datetime': '2017-06-07T04:35:50',
#               'surface_temperature_celsius': 61}]}
# {'_id': 94,
#  'air_temperature_celsius': 17,
#  'hotspot': [{'confidence': 89,
#               'datetime': '2017-04-05T03:39:10',
#               'surface_temperature_celsius': 64},
#              {'confidence': 88,
#               'datetime': '2017-04-05T13:02:40',
#               'surface_temperature_celsius': 42},
#              {'confidence': 88,
#               'datetime': '2017-04-05T03:39:10',
#               'surface_temperature_celsius': 63},
#              {'confidence': 87,
#               'datetime': '2017-04-05T05:16:50',
#               'surface_temperature_celsius': 88},
#              {'confidence': 83,
#               'datetime': '2017-04-05T03:39:10',
#               'surface_temperature_celsius': 64},
#              {'confidence': 81,
#               'datetime': '2017-04-05T13:03:00',
#               'surface_temperature_celsius': 39},
#              {'confidence': 83,
#               'datetime': '2017-04-05T03:39:20',
#               'surface_temperature_celsius': 56},
#              {'confidence': 81,
#               'datetime': '2017-04-05T13:09:00',
#               'surface_temperature_celsius': 39},
#              {'confidence': 82,
#               'datetime': '2017-04-05T13:07:00',
#               'surface_temperature_celsius': 40},
#              {'confidence': 81,
#               'datetime': '2017-04-05T03:40:20',
#               'surface_temperature_celsius': 54},
#              {'confidence': 89,
#               'datetime': '2017-04-05T03:39:30',
#               'surface_temperature_celsius': 65},
#              {'confidence': 82,
#               'datetime': '2017-04-05T03:39:30',
#               'surface_temperature_celsius': 62},
#              {'confidence': 89,
#               'datetime': '2017-04-05T03:39:10',
#               'surface_temperature_celsius': 65}]}
# {'_id': 92,
#  'air_temperature_celsius': 15,
#  'hotspot': [{'confidence': 82,
#               'datetime': '2017-04-03T03:50:40',
#               'surface_temperature_celsius': 55},
#              {'confidence': 86,
#               'datetime': '2017-04-03T03:50:40',
#               'surface_temperature_celsius': 60},
#              {'confidence': 85,
#               'datetime': '2017-04-03T03:50:40',
#               'surface_temperature_celsius': 61},
#              {'confidence': 81,
#               'datetime': '2017-04-03T03:51:00',
#               'surface_temperature_celsius': 54},
#              {'confidence': 89,
#               'datetime': '2017-04-03T03:50:40',
#               'surface_temperature_celsius': 65},
#              {'confidence': 87,
#               'datetime': '2017-04-03T03:51:10',
#               'surface_temperature_celsius': 62},
#              {'confidence': 88,
#               'datetime': '2017-04-03T03:55:10',
#               'surface_temperature_celsius': 64},
#              {'confidence': 82,
#               'datetime': '2017-04-03T03:56:20',
#               'surface_temperature_celsius': 55},
#              {'confidence': 87,
#               'datetime': '2017-04-03T03:59:10',
#               'surface_temperature_celsius': 96},
#              {'confidence': 86,
#               'datetime': '2017-04-03T03:52:10',
#               'surface_temperature_celsius': 61},
#              {'confidence': 81,
#               'datetime': '2017-04-03T01:07:20',
#               'surface_temperature_celsius': 54},
#              {'confidence': 89,
#               'datetime': '2017-04-03T03:50:40',
#               'surface_temperature_celsius': 65},
#              {'confidence': 83,
#               'datetime': '2017-04-03T13:15:30',
#               'surface_temperature_celsius': 40},
#              {'confidence': 85,
#               'datetime': '2017-04-03T03:53:30',
#               'surface_temperature_celsius': 59},
#              {'confidence': 84,
#               'datetime': '2017-04-03T03:52:30',
#               'surface_temperature_celsius': 58},
#              {'confidence': 85,
#               'datetime': '2017-04-03T03:52:10',
#               'surface_temperature_celsius': 59},
#              {'confidence': 87,
#               'datetime': '2017-04-03T03:50:50',
#               'surface_temperature_celsius': 97},
#              {'confidence': 83,
#               'datetime': '2017-04-03T03:51:30',
#               'surface_temperature_celsius': 63},
#              {'confidence': 89,
#               'datetime': '2017-04-03T03:51:30',
#               'surface_temperature_celsius': 66}]}
# {'_id': 89,
#  'air_temperature_celsius': 14,
#  'hotspot': [{'confidence': 82,
#               'datetime': '2017-03-31T05:07:10',
#               'surface_temperature_celsius': 55},
#              {'confidence': 82,
#               'datetime': '2017-03-31T04:58:30',
#               'surface_temperature_celsius': 56},
#              {'confidence': 81,
#               'datetime': '2017-03-31T00:36:30',
#               'surface_temperature_celsius': 54},
#              {'confidence': 86,
#               'datetime': '2017-03-31T04:57:10',
#               'surface_temperature_celsius': 61},
#              {'confidence': 87,
#               'datetime': '2017-03-31T05:01:20',
#               'surface_temperature_celsius': 62}]}
# {'_id': 342,
#  'air_temperature_celsius': 17,
#  'hotspot': [{'confidence': 86,
#               'datetime': '2017-12-09T00:14:33',
#               'surface_temperature_celsius': 60},
#              {'confidence': 84,
#               'datetime': '2017-12-09T00:14:33',
#               'surface_temperature_celsius': 58},
#              {'confidence': 81,
#               'datetime': '2017-12-09T00:14:34',
#               'surface_temperature_celsius': 54},
#              {'confidence': 87,
#               'datetime': '2017-12-09T00:14:34',
#               'surface_temperature_celsius': 61}]}
# {'_id': 68,
#  'air_temperature_celsius': 19,
#  'hotspot': [{'confidence': 81,
#               'datetime': '2017-03-10T04:43:50',
#               'surface_temperature_celsius': 55}]}
# {'_id': 67,
#  'air_temperature_celsius': 23,
#  'hotspot': [{'confidence': 86,
#               'datetime': '2017-03-09T13:23:40',
#               'surface_temperature_celsius': 41}]}
# {'_id': 114,
#  'air_temperature_celsius': 14,
#  'hotspot': [{'confidence': 82,
#               'datetime': '2017-04-25T05:02:30',
#               'surface_temperature_celsius': 56}]}
# {'_id': 65,
#  'air_temperature_celsius': 19,
#  'hotspot': [{'confidence': 88,
#               'datetime': '2017-03-07T04:16:10',
#               'surface_temperature_celsius': 64}]}
# {'_id': 324,
#  'air_temperature_celsius': 24,
#  'hotspot': [{'confidence': 85,
#               'datetime': '2017-11-21T00:27:21',
#               'surface_temperature_celsius': 59}]}
# {'_id': 112,
#  'air_temperature_celsius': 17,
#  'hotspot': [{'confidence': 81,
#               'datetime': '2017-04-23T05:02:50',
#               'surface_temperature_celsius': 54},
#              {'confidence': 88,
#               'datetime': '2017-04-23T05:03:40',
#               'surface_temperature_celsius': 64}]}
# {'_id': 326,
#  'air_temperature_celsius': 24,
#  'hotspot': [{'confidence': 84,
#               'datetime': '2017-11-23T04:28:59',
#               'surface_temperature_celsius': 60}]}
# {'_id': 64,
#  'air_temperature_celsius': 20,
#  'hotspot': [{'confidence': 85,
#               'datetime': '2017-03-06T05:06:20',
#               'surface_temperature_celsius': 59},
#              {'confidence': 87,
#               'datetime': '2017-03-06T05:06:30',
#               'surface_temperature_celsius': 62}]}
# {'_id': 111,
#  'air_temperature_celsius': 18,
#  'hotspot': [{'confidence': 87,
#               'datetime': '2017-04-22T04:20:20',
#               'surface_temperature_celsius': 62}]}
# {'_id': 317,
#  'air_temperature_celsius': 28,
#  'hotspot': [{'confidence': 87,
#               'datetime': '2017-11-14T04:35:04',
#               'surface_temperature_celsius': 65}]}
# {'_id': 86,
#  'air_temperature_celsius': 18,
#  'hotspot': [{'confidence': 84,
#               'datetime': '2017-03-28T04:26:50',
#               'surface_temperature_celsius': 58},
#              {'confidence': 87,
#               'datetime': '2017-03-28T04:26:50',
#               'surface_temperature_celsius': 62},
#              {'confidence': 87,
#               'datetime': '2017-03-28T04:26:50',
#               'surface_temperature_celsius': 62},
#              {'confidence': 85,
#               'datetime': '2017-03-28T04:26:50',
#               'surface_temperature_celsius': 59},
#              {'confidence': 81,
#               'datetime': '2017-03-28T04:30:10',
#               'surface_temperature_celsius': 54},
#              {'confidence': 88,
#               'datetime': '2017-03-28T04:26:50',
#               'surface_temperature_celsius': 63},
#              {'confidence': 83,
#               'datetime': '2017-03-28T04:30:50',
#               'surface_temperature_celsius': 56},
#              {'confidence': 83,
#               'datetime': '2017-03-28T04:26:50',
#               'surface_temperature_celsius': 57},
#              {'confidence': 83,
#               'datetime': '2017-03-28T04:26:50',
#               'surface_temperature_celsius': 57},
#              {'confidence': 81,
#               'datetime': '2017-03-28T04:26:50',
#               'surface_temperature_celsius': 55},
#              {'confidence': 86,
#               'datetime': '2017-03-28T04:33:40',
#               'surface_temperature_celsius': 60},
#              {'confidence': 88,
#               'datetime': '2017-03-28T04:38:00',
#               'surface_temperature_celsius': 64},
#              {'confidence': 81,
#               'datetime': '2017-03-28T04:28:30',
#               'surface_temperature_celsius': 54},
#              {'confidence': 87,
#               'datetime': '2017-03-28T04:28:30',
#               'surface_temperature_celsius': 62},
#              {'confidence': 85,
#               'datetime': '2017-03-28T04:26:50',
#               'surface_temperature_celsius': 60},
#              {'confidence': 88,
#               'datetime': '2017-03-28T04:28:30',
#               'surface_temperature_celsius': 63},
#              {'confidence': 82,
#               'datetime': '2017-03-28T04:27:00',
#               'surface_temperature_celsius': 55}]}
# {'_id': 141,
#  'air_temperature_celsius': 17,
#  'hotspot': [{'confidence': 89,
#               'datetime': '2017-05-22T00:13:00',
#               'surface_temperature_celsius': 64},
#              {'confidence': 85,
#               'datetime': '2017-05-22T00:15:00',
#               'surface_temperature_celsius': 59},
#              {'confidence': 89,
#               'datetime': '2017-05-22T04:32:20',
#               'surface_temperature_celsius': 65}]}
# {'_id': 273,
#  'air_temperature_celsius': 12,
#  'hotspot': [{'confidence': 89,
#               'datetime': '2017-10-01T04:10:28',
#               'surface_temperature_celsius': 61},
#              {'confidence': 84,
#               'datetime': '2017-10-01T04:10:28',
#               'surface_temperature_celsius': 52}]}
# {'_id': 75,
#  'air_temperature_celsius': 18,
#  'hotspot': [{'confidence': 86,
#               'datetime': '2017-03-17T04:45:00',
#               'surface_temperature_celsius': 60},
#              {'confidence': 84,
#               'datetime': '2017-03-17T04:45:10',
#               'surface_temperature_celsius': 59}]}
# {'_id': 122,
#  'air_temperature_celsius': 10,
#  'hotspot': [{'confidence': 84,
#               'datetime': '2017-05-03T04:02:20',
#               'surface_temperature_celsius': 58},
#              {'confidence': 87,
#               'datetime': '2017-05-03T04:02:20',
#               'surface_temperature_celsius': 63},
#              {'confidence': 85,
#               'datetime': '2017-05-03T04:02:20',
#               'surface_temperature_celsius': 60},
#              {'confidence': 84,
#               'datetime': '2017-05-03T04:02:20',
#               'surface_temperature_celsius': 58},
#              {'confidence': 88,
#               'datetime': '2017-05-03T04:02:20',
#               'surface_temperature_celsius': 64},
#              {'confidence': 82,
#               'datetime': '2017-05-03T04:08:10',
#               'surface_temperature_celsius': 55},
#              {'confidence': 86,
#               'datetime': '2017-05-03T04:06:40',
#               'surface_temperature_celsius': 60},
#              {'confidence': 84,
#               'datetime': '2017-05-03T04:02:20',
#               'surface_temperature_celsius': 58},
#              {'confidence': 84,
#               'datetime': '2017-05-03T04:05:20',
#               'surface_temperature_celsius': 57},
#              {'confidence': 86,
#               'datetime': '2017-05-03T04:03:00',
#               'surface_temperature_celsius': 60}]}
# {'_id': 252,
#  'air_temperature_celsius': 11,
#  'hotspot': [{'confidence': 81,
#               'datetime': '2017-09-10T03:50:10',
#               'surface_temperature_celsius': 54},
#              {'confidence': 86,
#               'datetime': '2017-09-10T03:50:30',
#               'surface_temperature_celsius': 60},
#              {'confidence': 84,
#               'datetime': '2017-09-10T03:53:00',
#               'surface_temperature_celsius': 58}]}
# {'_id': 93,
#  'air_temperature_celsius': 16,
#  'hotspot': [{'confidence': 87,
#               'datetime': '2017-04-04T04:32:40',
#               'surface_temperature_celsius': 92},
#              {'confidence': 83,
#               'datetime': '2017-04-04T04:34:50',
#               'surface_temperature_celsius': 57},
#              {'confidence': 88,
#               'datetime': '2017-04-04T04:37:10',
#               'surface_temperature_celsius': 64},
#              {'confidence': 87,
#               'datetime': '2017-04-04T04:36:10',
#               'surface_temperature_celsius': 62},
#              {'confidence': 81,
#               'datetime': '2017-04-04T04:39:40',
#               'surface_temperature_celsius': 54},
#              {'confidence': 86,
#               'datetime': '2017-04-04T04:41:00',
#               'surface_temperature_celsius': 61},
#              {'confidence': 85,
#               'datetime': '2017-04-04T04:39:50',
#               'surface_temperature_celsius': 66},
#              {'confidence': 82,
#               'datetime': '2017-04-04T04:41:10',
#               'surface_temperature_celsius': 62},
#              {'confidence': 85,
#               'datetime': '2017-04-04T04:34:20',
#               'surface_temperature_celsius': 66},
#              {'confidence': 88,
#               'datetime': '2017-04-04T04:36:10',
#               'surface_temperature_celsius': 63},
#              {'confidence': 88,
#               'datetime': '2017-04-04T04:41:00',
#               'surface_temperature_celsius': 64},
#              {'confidence': 82,
#               'datetime': '2017-04-04T04:32:50',
#               'surface_temperature_celsius': 55},
#              {'confidence': 89,
#               'datetime': '2017-04-04T04:34:20',
#               'surface_temperature_celsius': 65},
#              {'confidence': 82,
#               'datetime': '2017-04-04T04:32:50',
#               'surface_temperature_celsius': 55},
#              {'confidence': 82,
#               'datetime': '2017-04-04T04:33:10',
#               'surface_temperature_celsius': 62},
#              {'confidence': 81,
#               'datetime': '2017-04-04T04:32:40',
#               'surface_temperature_celsius': 54},
#              {'confidence': 84,
#               'datetime': '2017-04-04T04:34:00',
#               'surface_temperature_celsius': 57},
#              {'confidence': 82,
#               'datetime': '2017-04-04T04:33:10',
#               'surface_temperature_celsius': 62},
#              {'confidence': 88,
#               'datetime': '2017-04-04T04:41:50',
#               'surface_temperature_celsius': 63},
#              {'confidence': 81,
#               'datetime': '2017-04-04T04:33:40',
#               'surface_temperature_celsius': 54},
#              {'confidence': 85,
#               'datetime': '2017-04-04T04:33:30',
#               'surface_temperature_celsius': 59},
#              {'confidence': 86,
#               'datetime': '2017-04-04T04:33:00',
#               'surface_temperature_celsius': 61},
#              {'confidence': 84,
#               'datetime': '2017-04-04T04:32:50',
#               'surface_temperature_celsius': 58},
#              {'confidence': 85,
#               'datetime': '2017-04-04T04:32:50',
#               'surface_temperature_celsius': 61}]}
# {'_id': 70,
#  'air_temperature_celsius': 21,
#  'hotspot': [{'confidence': 85,
#               'datetime': '2017-03-12T04:27:20',
#               'surface_temperature_celsius': 98},
#              {'confidence': 84,
#               'datetime': '2017-03-12T04:29:50',
#               'surface_temperature_celsius': 71}]}
# {'_id': 159,
#  'air_temperature_celsius': 10,
#  'hotspot': [{'confidence': 86,
#               'datetime': '2017-06-09T04:23:16',
#               'surface_temperature_celsius': 56},
#              {'confidence': 84,
#               'datetime': '2017-06-09T04:23:20',
#               'surface_temperature_celsius': 52}]}
# {'_id': 95,
#  'air_temperature_celsius': 19,
#  'hotspot': [{'confidence': 86,
#               'datetime': '2017-04-06T04:20:40',
#               'surface_temperature_celsius': 72},
#              {'confidence': 87,
#               'datetime': '2017-04-06T04:20:40',
#               'surface_temperature_celsius': 62},
#              {'confidence': 87,
#               'datetime': '2017-04-06T04:20:40',
#               'surface_temperature_celsius': 62},
#              {'confidence': 85,
#               'datetime': '2017-04-06T04:20:40',
#               'surface_temperature_celsius': 60},
#              {'confidence': 81,
#               'datetime': '2017-04-06T04:20:40',
#               'surface_temperature_celsius': 61},
#              {'confidence': 89,
#               'datetime': '2017-04-06T04:24:00',
#               'surface_temperature_celsius': 64},
#              {'confidence': 86,
#               'datetime': '2017-04-06T04:27:00',
#               'surface_temperature_celsius': 60},
#              {'confidence': 88,
#               'datetime': '2017-04-06T04:20:50',
#               'surface_temperature_celsius': 65},
#              {'confidence': 84,
#               'datetime': '2017-04-06T04:32:20',
#               'surface_temperature_celsius': 65},
#              {'confidence': 89,
#               'datetime': '2017-04-06T04:23:10',
#               'surface_temperature_celsius': 65},
#              {'confidence': 87,
#               'datetime': '2017-04-06T04:23:00',
#               'surface_temperature_celsius': 62},
#              {'confidence': 83,
#               'datetime': '2017-04-06T04:22:20',
#               'surface_temperature_celsius': 56},
#              {'confidence': 83,
#               'datetime': '2017-04-06T04:27:00',
#               'surface_temperature_celsius': 57},
#              {'confidence': 89,
#               'datetime': '2017-04-06T04:24:20',
#               'surface_temperature_celsius': 65},
#              {'confidence': 89,
#               'datetime': '2017-04-06T04:24:20',
#               'surface_temperature_celsius': 65},
#              {'confidence': 85,
#               'datetime': '2017-04-06T04:22:20',
#               'surface_temperature_celsius': 60},
#              {'confidence': 85,
#               'datetime': '2017-04-06T04:22:40',
#               'surface_temperature_celsius': 60},
#              {'confidence': 86,
#               'datetime': '2017-04-06T04:22:10',
#               'surface_temperature_celsius': 68},
#              {'confidence': 81,
#               'datetime': '2017-04-06T04:20:40',
#               'surface_temperature_celsius': 57},
#              {'confidence': 81,
#               'datetime': '2017-04-06T04:20:40',
#               'surface_temperature_celsius': 60},
#              {'confidence': 85,
#               'datetime': '2017-04-06T04:22:10',
#               'surface_temperature_celsius': 59},
#              {'confidence': 84,
#               'datetime': '2017-04-06T04:20:40',
#               'surface_temperature_celsius': 57},
#              {'confidence': 84,
#               'datetime': '2017-04-06T04:21:00',
#               'surface_temperature_celsius': 58},
#              {'confidence': 87,
#               'datetime': '2017-04-06T04:20:40',
#               'surface_temperature_celsius': 62},
#              {'confidence': 83,
#               'datetime': '2017-04-06T04:24:40',
#               'surface_temperature_celsius': 64},
#              {'confidence': 81,
#               'datetime': '2017-04-06T04:27:10',
#               'surface_temperature_celsius': 54},
#              {'confidence': 83,
#               'datetime': '2017-04-06T04:20:50',
#               'surface_temperature_celsius': 63},
#              {'confidence': 81,
#               'datetime': '2017-04-06T04:22:20',
#               'surface_temperature_celsius': 71},
#              {'confidence': 83,
#               'datetime': '2017-04-06T04:20:40',
#               'surface_temperature_celsius': 78},
#              {'confidence': 82,
#               'datetime': '2017-04-06T04:20:40',
#               'surface_temperature_celsius': 56}]}
# {'_id': 72,
#  'air_temperature_celsius': 25,
#  'hotspot': [{'confidence': 81,
#               'datetime': '2017-03-14T04:14:40',
#               'surface_temperature_celsius': 55},
#              {'confidence': 89,
#               'datetime': '2017-03-14T04:16:20',
#               'surface_temperature_celsius': 65}]}
# {'_id': 83,
#  'air_temperature_celsius': 23,
#  'hotspot': [{'confidence': 85,
#               'datetime': '2017-03-25T03:57:10',
#               'surface_temperature_celsius': 59},
#              {'confidence': 87,
#               'datetime': '2017-03-25T03:58:10',
#               'surface_temperature_celsius': 62},
#              {'confidence': 82,
#               'datetime': '2017-03-25T03:59:50',
#               'surface_temperature_celsius': 65}]}
# {'_id': 299,
#  'air_temperature_celsius': 22,
#  'hotspot': [{'confidence': 86,
#               'datetime': '2017-10-27T04:47:31',
#               'surface_temperature_celsius': 60}]}
# {'_id': 132,
#  'air_temperature_celsius': 9,
#  'hotspot': [{'confidence': 85,
#               'datetime': '2017-05-13T04:38:40',
#               'surface_temperature_celsius': 60},
#              {'confidence': 86,
#               'datetime': '2017-05-13T04:38:40',
#               'surface_temperature_celsius': 60},
#              {'confidence': 82,
#               'datetime': '2017-05-13T04:38:40',
#               'surface_temperature_celsius': 55},
#              {'confidence': 82,
#               'datetime': '2017-05-13T04:38:40',
#               'surface_temperature_celsius': 56},
#              {'confidence': 85,
#               'datetime': '2017-05-13T04:39:00',
#               'surface_temperature_celsius': 60},
#              {'confidence': 83,
#               'datetime': '2017-05-13T04:39:30',
#               'surface_temperature_celsius': 63},
#              {'confidence': 86,
#               'datetime': '2017-05-13T04:38:40',
#               'surface_temperature_celsius': 60},
#              {'confidence': 81,
#               'datetime': '2017-05-13T04:38:40',
#               'surface_temperature_celsius': 54},
#              {'confidence': 84,
#               'datetime': '2017-05-13T04:38:40',
#               'surface_temperature_celsius': 57},
#              {'confidence': 87,
#               'datetime': '2017-05-13T04:38:40',
#               'surface_temperature_celsius': 62},
#              {'confidence': 81,
#               'datetime': '2017-05-13T04:39:50',
#               'surface_temperature_celsius': 55},
#              {'confidence': 85,
#               'datetime': '2017-05-13T04:38:40',
#               'surface_temperature_celsius': 60},
#              {'confidence': 84,
#               'datetime': '2017-05-13T04:38:40',
#               'surface_temperature_celsius': 58},
#              {'confidence': 87,
#               'datetime': '2017-05-13T04:38:40',
#               'surface_temperature_celsius': 62}]}
# {'_id': 276,
#  'air_temperature_celsius': 19,
#  'hotspot': [{'confidence': 88,
#               'datetime': '2017-10-04T04:41:00',
#               'surface_temperature_celsius': 58},
#              {'confidence': 85,
#               'datetime': '2017-10-04T04:41:00',
#               'surface_temperature_celsius': 54}]}
# {'_id': 100,
#  'air_temperature_celsius': 14,
#  'hotspot': [{'confidence': 85,
#               'datetime': '2017-04-11T04:39:00',
#               'surface_temperature_celsius': 60},
#              {'confidence': 84,
#               'datetime': '2017-04-11T04:39:00',
#               'surface_temperature_celsius': 58},
#              {'confidence': 81,
#               'datetime': '2017-04-11T04:39:20',
#               'surface_temperature_celsius': 54}]}
# {'_id': 77,
#  'air_temperature_celsius': 24,
#  'hotspot': [{'confidence': 84,
#               'datetime': '2017-03-19T04:32:50',
#               'surface_temperature_celsius': 58},
#              {'confidence': 85,
#               'datetime': '2017-03-19T04:39:50',
#               'surface_temperature_celsius': 60}]}
# {'_id': 275,
#  'air_temperature_celsius': 13,
#  'hotspot': [{'confidence': 87,
#               'datetime': '2017-10-03T03:58:14',
#               'surface_temperature_celsius': 59},
#              {'confidence': 81,
# ...
#               'datetime': '2017-04-18T04:45:30',
#               'surface_temperature_celsius': 60},
#              {'confidence': 82,
#               'datetime': '2017-04-18T04:45:40',
#               'surface_temperature_celsius': 55},
#              {'confidence': 88,
#               'datetime': '2017-04-18T04:48:10',
#               'surface_temperature_celsius': 64},
#              {'confidence': 85,
#               'datetime': '2017-04-18T04:46:30',
#               'surface_temperature_celsius': 59},
#              {'confidence': 88,
#               'datetime': '2017-04-18T04:48:20',
#               'surface_temperature_celsius': 64},
#              {'confidence': 83,
#               'datetime': '2017-04-18T00:24:40',
#               'surface_temperature_celsius': 56},
#              {'confidence': 82,
#               'datetime': '2017-04-18T04:45:50',
#               'surface_temperature_celsius': 55},
#              {'confidence': 83,
#               'datetime': '2017-04-18T04:48:20',
#               'surface_temperature_celsius': 56},
#              {'confidence': 82,
#               'datetime': '2017-04-18T04:55:00',
#               'surface_temperature_celsius': 56},
#              {'confidence': 85,
#               'datetime': '2017-04-18T04:52:00',
#               'surface_temperature_celsius': 59},
#              {'confidence': 82,
#               'datetime': '2017-04-18T04:51:20',
#               'surface_temperature_celsius': 56},
#              {'confidence': 86,
#               'datetime': '2017-04-18T04:45:00',
#               'surface_temperature_celsius': 61},
#              {'confidence': 83,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 56},
#              {'confidence': 82,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 56},
#              {'confidence': 86,
#               'datetime': '2017-04-18T04:52:20',
#               'surface_temperature_celsius': 60},
#              {'confidence': 89,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 65},
#              {'confidence': 87,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 62},
#              {'confidence': 89,
#               'datetime': '2017-04-18T04:51:30',
#               'surface_temperature_celsius': 65},
#              {'confidence': 89,
#               'datetime': '2017-04-18T00:30:40',
#               'surface_temperature_celsius': 66},
#              {'confidence': 89,
#               'datetime': '2017-04-18T04:51:30',
#               'surface_temperature_celsius': 66},
#              {'confidence': 86,
#               'datetime': '2017-04-18T04:56:20',
#               'surface_temperature_celsius': 61},
#              {'confidence': 88,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 64},
#              {'confidence': 88,
#               'datetime': '2017-04-18T04:49:50',
#               'surface_temperature_celsius': 63},
#              {'confidence': 81,
#               'datetime': '2017-04-18T04:45:00',
#               'surface_temperature_celsius': 54},
#              {'confidence': 89,
#               'datetime': '2017-04-18T04:45:20',
#               'surface_temperature_celsius': 65},
#              {'confidence': 84,
#               'datetime': '2017-04-18T04:45:00',
#               'surface_temperature_celsius': 58},
#              {'confidence': 82,
#               'datetime': '2017-04-18T04:51:30',
#               'surface_temperature_celsius': 58},
#              {'confidence': 84,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 66},
#              {'confidence': 81,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 54},
#              {'confidence': 85,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 60},
#              {'confidence': 81,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 54},
#              {'confidence': 85,
#               'datetime': '2017-04-18T04:48:10',
#               'surface_temperature_celsius': 59},
#              {'confidence': 87,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 62},
#              {'confidence': 87,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 61},
#              {'confidence': 87,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 62},
#              {'confidence': 89,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 64},
#              {'confidence': 85,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 60},
#              {'confidence': 86,
#               'datetime': '2017-04-18T04:48:10',
#               'surface_temperature_celsius': 61},
#              {'confidence': 81,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 60},
#              {'confidence': 81,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 54},
#              {'confidence': 81,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 54},
#              {'confidence': 82,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 56},
#              {'confidence': 81,
#               'datetime': '2017-04-18T04:45:20',
#               'surface_temperature_celsius': 54},
#              {'confidence': 86,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 61},
#              {'confidence': 86,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 60},
#              {'confidence': 84,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 57},
#              {'confidence': 81,
#               'datetime': '2017-04-18T04:51:20',
#               'surface_temperature_celsius': 55},
#              {'confidence': 84,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 58},
#              {'confidence': 86,
#               'datetime': '2017-04-18T04:44:50',
#               'surface_temperature_celsius': 61}]}
# {'_id': 308,
#  'air_temperature_celsius': 13,
#  'hotspot': [{'confidence': 89,
#               'datetime': '2017-11-05T04:41:19',
#               'surface_temperature_celsius': 62},
#              {'confidence': 83,
#               'datetime': '2017-11-05T04:41:34',
#               'surface_temperature_celsius': 58}]}
# {'_id': 108,
#  'air_temperature_celsius': 22,
#  'hotspot': [{'confidence': 85,
#               'datetime': '2017-04-19T03:50:30',
#               'surface_temperature_celsius': 59},
#              {'confidence': 84,
#               'datetime': '2017-04-19T03:50:30',
#               'surface_temperature_celsius': 58},
#              {'confidence': 88,
#               'datetime': '2017-04-19T03:50:30',
#               'surface_temperature_celsius': 64},
#              {'confidence': 86,
#               'datetime': '2017-04-19T03:50:50',
#               'surface_temperature_celsius': 61},
#              {'confidence': 88,
#               'datetime': '2017-04-19T13:15:10',
#               'surface_temperature_celsius': 42},
#              {'confidence': 87,
#               'datetime': '2017-04-19T03:52:00',
#               'surface_temperature_celsius': 70},
#              {'confidence': 87,
#               'datetime': '2017-04-19T03:53:20',
#               'surface_temperature_celsius': 62},
#              {'confidence': 83,
#               'datetime': '2017-04-19T13:18:20',
#               'surface_temperature_celsius': 40},
#              {'confidence': 89,
#               'datetime': '2017-04-19T03:52:10',
#               'surface_temperature_celsius': 65},
#              {'confidence': 88,
#               'datetime': '2017-04-19T03:52:10',
#               'surface_temperature_celsius': 74},
#              {'confidence': 88,
#               'datetime': '2017-04-19T03:52:10',
#               'surface_temperature_celsius': 64},
#              {'confidence': 81,
#               'datetime': '2017-04-19T13:15:10',
#               'surface_temperature_celsius': 39},
#              {'confidence': 84,
#               'datetime': '2017-04-19T03:51:50',
#               'surface_temperature_celsius': 58},
#              {'confidence': 84,
#               'datetime': '2017-04-19T03:50:30',
#               'surface_temperature_celsius': 58},
#              {'confidence': 82,
#               'datetime': '2017-04-19T03:51:50',
#               'surface_temperature_celsius': 56}]}
# {'_id': 312,
#  'air_temperature_celsius': 14,
#  'hotspot': [{'confidence': 87,
#               'datetime': '2017-11-09T04:16:44',
#               'surface_temperature_celsius': 62},
#              {'confidence': 85,
#               'datetime': '2017-11-09T04:16:48',
#               'surface_temperature_celsius': 59}]}
# {'_id': 109,
#  'air_temperature_celsius': 20,
#  'hotspot': [{'confidence': 89,
#               'datetime': '2017-04-20T00:13:40',
#               'surface_temperature_celsius': 64},
#              {'confidence': 88,
#               'datetime': '2017-04-20T00:18:40',
#               'surface_temperature_celsius': 63},
#              {'confidence': 84,
#               'datetime': '2017-04-20T04:44:20',
#               'surface_temperature_celsius': 58},
#              {'confidence': 88,
#               'datetime': '2017-04-20T04:33:20',
#               'surface_temperature_celsius': 63},
#              {'confidence': 85,
#               'datetime': '2017-04-20T04:32:30',
#               'surface_temperature_celsius': 60},
#              {'confidence': 87,
#               'datetime': '2017-04-20T04:32:30',
#               'surface_temperature_celsius': 62}]}
# {'_id': 113,
#  'air_temperature_celsius': 19,
#  'hotspot': [{'confidence': 86,
#               'datetime': '2017-04-24T04:08:20',
#               'surface_temperature_celsius': 78}]}
# {'_id': 118,
#  'air_temperature_celsius': 15,
#  'hotspot': [{'confidence': 87,
#               'datetime': '2017-04-29T04:33:00',
#               'surface_temperature_celsius': 90}]}
# {'_id': 120,
#  'air_temperature_celsius': 14,
#  'hotspot': [{'confidence': 82,
#               'datetime': '2017-05-01T04:14:30',
#               'surface_temperature_celsius': 55},
#              {'confidence': 87,
#               'datetime': '2017-05-01T04:14:20',
#               'surface_temperature_celsius': 117},
#              {'confidence': 82,
#               'datetime': '2017-05-01T04:14:30',
#               'surface_temperature_celsius': 55},
#              {'confidence': 83,
#               'datetime': '2017-05-01T04:14:20',
#               'surface_temperature_celsius': 77},
#              {'confidence': 85,
#               'datetime': '2017-05-01T04:14:20',
#               'surface_temperature_celsius': 59},
#              {'confidence': 82,
#               'datetime': '2017-05-01T04:14:20',
#               'surface_temperature_celsius': 62}]}
# {'_id': 360,
#  'air_temperature_celsius': 28,
#  'hotspot': [{'confidence': 86,
#               'datetime': '2017-12-27T00:02:14',
#               'surface_temperature_celsius': 67},
#              {'confidence': 82,
#               'datetime': '2017-12-27T00:02:15',
#               'surface_temperature_celsius': 63}]}
# {'_id': 121,
#  'air_temperature_celsius': 10,
#  'hotspot': [{'confidence': 81,
#               'datetime': '2017-05-02T23:44:00',
#               'surface_temperature_celsius': 54}]}
# {'_id': 271,
#  'air_temperature_celsius': 14,
#  'hotspot': [{'confidence': 82,
#               'datetime': '2017-09-29T04:22:31',
#               'surface_temperature_celsius': 49}]}
# {'_id': 123,
#  'air_temperature_celsius': 10,
#  'hotspot': [{'confidence': 88,
#               'datetime': '2017-05-04T00:28:30',
#               'surface_temperature_celsius': 73},
#              {'confidence': 86,
#               'datetime': '2017-05-04T04:44:40',
#               'surface_temperature_celsius': 61},
#              {'confidence': 84,
#               'datetime': '2017-05-04T04:44:40',
#               'surface_temperature_celsius': 58},
#              {'confidence': 87,
#               'datetime': '2017-05-04T04:44:40',
#               'surface_temperature_celsius': 62},
#              {'confidence': 87,
#               'datetime': '2017-05-04T00:25:30',
#               'surface_temperature_celsius': 71},
#              {'confidence': 89,
#               'datetime': '2017-05-04T04:44:40',
#               'surface_temperature_celsius': 65},
#              {'confidence': 89,
#               'datetime': '2017-05-04T04:44:40',
#               'surface_temperature_celsius': 66},
#              {'confidence': 83,
#               'datetime': '2017-05-04T04:44:40',
#               'surface_temperature_celsius': 56},
#              {'confidence': 84,
#               'datetime': '2017-05-04T04:44:40',
#               'surface_temperature_celsius': 58},
#              {'confidence': 83,
#               'datetime': '2017-05-04T04:44:40',
#               'surface_temperature_celsius': 56},
#              {'confidence': 87,
#               'datetime': '2017-05-04T04:46:50',
#               'surface_temperature_celsius': 63},
#              {'confidence': 82,
#               'datetime': '2017-05-04T04:46:20',
#               'surface_temperature_celsius': 55},
#              {'confidence': 81,
#               'datetime': '2017-05-04T04:46:30',
#               'surface_temperature_celsius': 54},
#              {'confidence': 87,
#               'datetime': '2017-05-04T04:48:10',
#               'surface_temperature_celsius': 62},
#              {'confidence': 84,
#               'datetime': '2017-05-04T04:46:20',
#               'surface_temperature_celsius': 58},
#              {'confidence': 82,
#               'datetime': '2017-05-04T04:45:40',
#               'surface_temperature_celsius': 55},
#              {'confidence': 81,
#               'datetime': '2017-05-04T04:45:40',
#               'surface_temperature_celsius': 54},
#              {'confidence': 87,
#               'datetime': '2017-05-04T04:45:30',
#               'surface_temperature_celsius': 61},
#              {'confidence': 84,
#               'datetime': '2017-05-04T04:44:40',
#               'surface_temperature_celsius': 58},
#              {'confidence': 81,
#               'datetime': '2017-05-04T04:44:50',
#               'surface_temperature_celsius': 55},
#              {'confidence': 81,
#               'datetime': '2017-05-04T04:44:50',
#               'surface_temperature_celsius': 54}]}
# {'_id': 125,
#  'air_temperature_celsius': 12,
#  'hotspot': [{'confidence': 83,
#               'datetime': '2017-05-06T00:16:40',
#               'surface_temperature_celsius': 57},
#              {'confidence': 85,
#               'datetime': '2017-05-06T04:32:30',
#               'surface_temperature_celsius': 59}]}
# {'_id': 127,
#  'air_temperature_celsius': 12,
#  'hotspot': [{'confidence': 86,
#               'datetime': '2017-05-08T04:20:10',
#               'surface_temperature_celsius': 60},
#              {'confidence': 83,
#               'datetime': '2017-05-08T04:20:20',
#               'surface_temperature_celsius': 56},
#              {'confidence': 87,
#               'datetime': '2017-05-08T04:24:00',
#               'surface_temperature_celsius': 62}]}
# {'_id': 128,
#  'air_temperature_celsius': 12,
#  'hotspot': [{'confidence': 81,
#               'datetime': '2017-05-09T05:02:50',
#               'surface_temperature_celsius': 54},
#              {'confidence': 81,
#               'datetime': '2017-05-09T12:56:40',
#               'surface_temperature_celsius': 39}]}
# {'_id': 130,
#  'air_temperature_celsius': 9,
#  'hotspot': [{'confidence': 84,
#               'datetime': '2017-05-11T04:50:40',
#               'surface_temperature_celsius': 78},
#              {'confidence': 89,
#               'datetime': '2017-05-11T04:51:00',
#               'surface_temperature_celsius': 65},
#              {'confidence': 88,
#               'datetime': '2017-05-11T04:54:00',
#               'surface_temperature_celsius': 63}]}

# %% [markdown]
# ## 12. (2E) Find the Top 10 Records with the Highest Surface Temperature

# %%
for i in db.climate.find({}).sort([('hotspot.surface_temperature_celsius', pymongo.DESCENDING)]).limit(10):
    indx_max = 0
    for j in range(len(i['hotspot'])):
        if i['hotspot'][j]['surface_temperature_celsius'] > i['hotspot'][indx_max]['surface_temperature_celsius']:
            indx_max = j
    pprint({
        '_id': i['_id'],
        'climate': i['climate'],
        'date': i['date'],
        'hotspot': i['hotspot'][indx_max]
    })
# Out:
# {'_id': 107,
#  'climate': {'air_temperature_celsius': 15,
#              'max_wind_speed': 9.9,
#              'precipitation': ' 0.00I',
#              'relative_humidity': 56.1,
#              'station': 948701,
#              'windspeed_knots': 5.1},
#  'date': '18/04/2017',
#  'hotspot': {'confidence': 100,
#              'datetime': '2017-04-18T04:52:00',
#              'latitude': -38.1665,
#              'longitude': 143.062,
#              'surface_temperature_celsius': 124}}
# {'_id': 93,
#  'climate': {'air_temperature_celsius': 16,
#              'max_wind_speed': 12.0,
#              'precipitation': ' 0.00I',
#              'relative_humidity': 47.5,
#              'station': 948701,
#              'windspeed_knots': 5.4},
#  'date': '4/04/2017',
#  'hotspot': {'confidence': 100,
#              'datetime': '2017-04-04T04:32:50',
#              'latitude': -36.343,
#              'longitude': 142.1986,
#              'surface_temperature_celsius': 123}}
# {'_id': 120,
#  'climate': {'air_temperature_celsius': 14,
#              'max_wind_speed': 20.0,
#              'precipitation': ' 0.12G',
#              'relative_humidity': 49.2,
#              'station': 948701,
#              'windspeed_knots': 10.5},
#  'date': '1/05/2017',
#  'hotspot': {'confidence': 100,
#              'datetime': '2017-05-01T04:14:20',
#              'latitude': -36.9318,
#              'longitude': 143.0907,
#              'surface_temperature_celsius': 122}}
# {'_id': 76,
#  'climate': {'air_temperature_celsius': 21,
#              'max_wind_speed': 11.1,
#              'precipitation': ' 0.00I',
#              'relative_humidity': 52.8,
#              'station': 948701,
#              'windspeed_knots': 4.1},
#  'date': '18/03/2017',
#  'hotspot': {'confidence': 100,
#              'datetime': '2017-03-18T03:50:50',
#              'latitude': -37.017,
#              'longitude': 148.1297,
#              'surface_temperature_celsius': 121}}
# {'_id': 102,
#  'climate': {'air_temperature_celsius': 16,
#              'max_wind_speed': 9.9,
#              'precipitation': ' 0.00I',
#              'relative_humidity': 54.9,
#              'station': 948701,
#              'windspeed_knots': 5.9},
#  'date': '13/04/2017',
#  'hotspot': {'confidence': 100,
#              'datetime': '2017-04-13T04:28:10',
#              'latitude': -37.0745,
#              'longitude': 141.0692,
#              'surface_temperature_celsius': 120}}
# {'_id': 132,
#  'climate': {'air_temperature_celsius': 9,
#              'max_wind_speed': 8.0,
#              'precipitation': ' 0.00I',
#              'relative_humidity': 44.0,
#              'station': 948701,
#              'windspeed_knots': 2.8},
#  'date': '13/05/2017',
#  'hotspot': {'confidence': 100,
#              'datetime': '2017-05-13T04:40:20',
#              'latitude': -34.9938,
#              'longitude': 141.876,
#              'surface_temperature_celsius': 120}}
# {'_id': 123,
#  'climate': {'air_temperature_celsius': 10,
#              'max_wind_speed': 7.0,
#              'precipitation': ' 0.00I',
#              'relative_humidity': 43.3,
#              'station': 948701,
#              'windspeed_knots': 2.6},
#  'date': '4/05/2017',
#  'hotspot': {'confidence': 100,
#              'datetime': '2017-05-04T04:44:50',
#              'latitude': -36.4057,
#              'longitude': 140.9806,
#              'surface_temperature_celsius': 119}}
# {'_id': 104,
#  'climate': {'air_temperature_celsius': 12,
#              'max_wind_speed': 7.0,
#              'precipitation': ' 0.00G',
#              'relative_humidity': 44.0,
#              'station': 948701,
#              'windspeed_knots': 4.7},
#  'date': '15/04/2017',
#  'hotspot': {'confidence': 100,
#              'datetime': '2017-04-15T04:14:30',
#              'latitude': -36.239,
#              'longitude': 143.3972,
#              'surface_temperature_celsius': 116}}
# {'_id': 92,
#  'climate': {'air_temperature_celsius': 15,
#              'max_wind_speed': 13.0,
#              'precipitation': ' 0.00I',
#              'relative_humidity': 47.7,
#              'station': 948701,
#              'windspeed_knots': 5.9},
#  'date': '3/04/2017',
#  'hotspot': {'confidence': 100,
#              'datetime': '2017-04-03T03:52:20',
#              'latitude': -37.3716,
#              'longitude': 145.9065,
#              'surface_temperature_celsius': 115}}
# {'_id': 95,
#  'climate': {'air_temperature_celsius': 19,
#              'max_wind_speed': 15.9,
#              'precipitation': ' 0.00I',
#              'relative_humidity': 44.2,
#              'station': 948701,
#              'windspeed_knots': 7.8},
#  'date': '6/04/2017',
#  'hotspot': {'confidence': 100,
#              'datetime': '2017-04-06T04:21:00',
#              'latitude': -37.8545,
#              'longitude': 142.5132,
#              'surface_temperature_celsius': 115}}

# %% [markdown]
# ## 13. (2F) Find the Number of Fires in Each Day

# %%
for i in db.climate.find({}, 
                         {'date': 1, 
                          'hotspot': 1, 
                          '_id': 1
                         }):
    pprint({
        '_id': i['_id'],
        'date': i['date'],
        'number_of_fires': len(i['hotspot'])
    })
# Out:
# {'_id': 0, 'date': '31/12/2016', 'number_of_fires': 0}
# {'_id': 1, 'date': '2/01/2017', 'number_of_fires': 0}
# {'_id': 2, 'date': '3/01/2017', 'number_of_fires': 0}
# {'_id': 3, 'date': '4/01/2017', 'number_of_fires': 0}
# {'_id': 4, 'date': '5/01/2017', 'number_of_fires': 0}
# {'_id': 5, 'date': '6/01/2017', 'number_of_fires': 0}
# {'_id': 6, 'date': '7/01/2017', 'number_of_fires': 0}
# {'_id': 7, 'date': '8/01/2017', 'number_of_fires': 0}
# {'_id': 8, 'date': '9/01/2017', 'number_of_fires': 0}
# {'_id': 9, 'date': '10/01/2017', 'number_of_fires': 0}
# {'_id': 10, 'date': '11/01/2017', 'number_of_fires': 0}
# {'_id': 11, 'date': '12/01/2017', 'number_of_fires': 0}
# {'_id': 12, 'date': '13/01/2017', 'number_of_fires': 0}
# {'_id': 13, 'date': '14/01/2017', 'number_of_fires': 0}
# {'_id': 14, 'date': '15/01/2017', 'number_of_fires': 0}
# {'_id': 15, 'date': '16/01/2017', 'number_of_fires': 0}
# {'_id': 16, 'date': '17/01/2017', 'number_of_fires': 0}
# {'_id': 17, 'date': '18/01/2017', 'number_of_fires': 0}
# {'_id': 18, 'date': '19/01/2017', 'number_of_fires': 0}
# {'_id': 19, 'date': '20/01/2017', 'number_of_fires': 0}
# {'_id': 20, 'date': '21/01/2017', 'number_of_fires': 0}
# {'_id': 21, 'date': '22/01/2017', 'number_of_fires': 0}
# {'_id': 22, 'date': '23/01/2017', 'number_of_fires': 0}
# {'_id': 23, 'date': '24/01/2017', 'number_of_fires': 0}
# {'_id': 24, 'date': '25/01/2017', 'number_of_fires': 0}
# {'_id': 25, 'date': '26/01/2017', 'number_of_fires': 0}
# {'_id': 26, 'date': '27/01/2017', 'number_of_fires': 0}
# {'_id': 27, 'date': '28/01/2017', 'number_of_fires': 0}
# {'_id': 28, 'date': '29/01/2017', 'number_of_fires': 0}
# {'_id': 29, 'date': '30/01/2017', 'number_of_fires': 0}
# {'_id': 30, 'date': '31/01/2017', 'number_of_fires': 0}
# {'_id': 31, 'date': '1/02/2017', 'number_of_fires': 0}
# {'_id': 32, 'date': '2/02/2017', 'number_of_fires': 0}
# {'_id': 33, 'date': '3/02/2017', 'number_of_fires': 0}
# {'_id': 34, 'date': '4/02/2017', 'number_of_fires': 0}
# {'_id': 35, 'date': '5/02/2017', 'number_of_fires': 0}
# {'_id': 36, 'date': '6/02/2017', 'number_of_fires': 0}
# {'_id': 37, 'date': '7/02/2017', 'number_of_fires': 0}
# {'_id': 38, 'date': '8/02/2017', 'number_of_fires': 0}
# {'_id': 39, 'date': '9/02/2017', 'number_of_fires': 0}
# {'_id': 40, 'date': '10/02/2017', 'number_of_fires': 0}
# {'_id': 41, 'date': '11/02/2017', 'number_of_fires': 0}
# {'_id': 42, 'date': '12/02/2017', 'number_of_fires': 0}
# {'_id': 43, 'date': '13/02/2017', 'number_of_fires': 0}
# {'_id': 44, 'date': '14/02/2017', 'number_of_fires': 0}
# {'_id': 45, 'date': '15/02/2017', 'number_of_fires': 0}
# {'_id': 46, 'date': '16/02/2017', 'number_of_fires': 0}
# {'_id': 47, 'date': '17/02/2017', 'number_of_fires': 0}
# {'_id': 48, 'date': '18/02/2017', 'number_of_fires': 0}
# {'_id': 49, 'date': '19/02/2017', 'number_of_fires': 0}
# {'_id': 50, 'date': '20/02/2017', 'number_of_fires': 0}
# {'_id': 51, 'date': '21/02/2017', 'number_of_fires': 0}
# {'_id': 52, 'date': '22/02/2017', 'number_of_fires': 0}
# {'_id': 53, 'date': '23/02/2017', 'number_of_fires': 0}
# {'_id': 54, 'date': '24/02/2017', 'number_of_fires': 0}
# {'_id': 55, 'date': '25/02/2017', 'number_of_fires': 0}
# {'_id': 56, 'date': '26/02/2017', 'number_of_fires': 0}
# {'_id': 57, 'date': '27/02/2017', 'number_of_fires': 0}
# {'_id': 58, 'date': '28/02/2017', 'number_of_fires': 0}
# {'_id': 59, 'date': '1/03/2017', 'number_of_fires': 0}
# {'_id': 60, 'date': '2/03/2017', 'number_of_fires': 0}
# {'_id': 61, 'date': '3/03/2017', 'number_of_fires': 0}
# {'_id': 62, 'date': '4/03/2017', 'number_of_fires': 0}
# {'_id': 63, 'date': '5/03/2017', 'number_of_fires': 0}
# {'_id': 64, 'date': '6/03/2017', 'number_of_fires': 2}
# {'_id': 65, 'date': '7/03/2017', 'number_of_fires': 1}
# {'_id': 66, 'date': '8/03/2017', 'number_of_fires': 2}
# {'_id': 67, 'date': '9/03/2017', 'number_of_fires': 3}
# {'_id': 68, 'date': '10/03/2017', 'number_of_fires': 8}
# {'_id': 69, 'date': '11/03/2017', 'number_of_fires': 0}
# {'_id': 70, 'date': '12/03/2017', 'number_of_fires': 5}
# {'_id': 71, 'date': '13/03/2017', 'number_of_fires': 2}
# {'_id': 72, 'date': '14/03/2017', 'number_of_fires': 10}
# {'_id': 73, 'date': '15/03/2017', 'number_of_fires': 7}
# {'_id': 74, 'date': '16/03/2017', 'number_of_fires': 0}
# {'_id': 75, 'date': '17/03/2017', 'number_of_fires': 6}
# {'_id': 76, 'date': '18/03/2017', 'number_of_fires': 3}
# {'_id': 77, 'date': '19/03/2017', 'number_of_fires': 21}
# {'_id': 78, 'date': '20/03/2017', 'number_of_fires': 0}
# {'_id': 79, 'date': '21/03/2017', 'number_of_fires': 0}
# {'_id': 80, 'date': '22/03/2017', 'number_of_fires': 0}
# {'_id': 81, 'date': '23/03/2017', 'number_of_fires': 0}
# {'_id': 82, 'date': '24/03/2017', 'number_of_fires': 2}
# {'_id': 83, 'date': '25/03/2017', 'number_of_fires': 13}
# {'_id': 84, 'date': '26/03/2017', 'number_of_fires': 17}
# {'_id': 85, 'date': '27/03/2017', 'number_of_fires': 0}
# {'_id': 86, 'date': '28/03/2017', 'number_of_fires': 54}
# {'_id': 87, 'date': '29/03/2017', 'number_of_fires': 1}
# {'_id': 88, 'date': '30/03/2017', 'number_of_fires': 0}
# {'_id': 89, 'date': '31/03/2017', 'number_of_fires': 22}
# {'_id': 90, 'date': '1/04/2017', 'number_of_fires': 7}
# {'_id': 91, 'date': '2/04/2017', 'number_of_fires': 5}
# {'_id': 92, 'date': '3/04/2017', 'number_of_fires': 72}
# {'_id': 93, 'date': '4/04/2017', 'number_of_fires': 89}
# {'_id': 94, 'date': '5/04/2017', 'number_of_fires': 49}
# {'_id': 95, 'date': '6/04/2017', 'number_of_fires': 118}
# {'_id': 96, 'date': '7/04/2017', 'number_of_fires': 39}
# {'_id': 97, 'date': '8/04/2017', 'number_of_fires': 20}
# {'_id': 98, 'date': '9/04/2017', 'number_of_fires': 0}
# {'_id': 99, 'date': '10/04/2017', 'number_of_fires': 0}
# {'_id': 100, 'date': '11/04/2017', 'number_of_fires': 24}
# {'_id': 101, 'date': '12/04/2017', 'number_of_fires': 69}
# {'_id': 102, 'date': '13/04/2017', 'number_of_fires': 357}
# {'_id': 103, 'date': '14/04/2017', 'number_of_fires': 18}
# {'_id': 104, 'date': '15/04/2017', 'number_of_fires': 69}
# {'_id': 105, 'date': '16/04/2017', 'number_of_fires': 18}
# {'_id': 106, 'date': '17/04/2017', 'number_of_fires': 38}
# {'_id': 107, 'date': '18/04/2017', 'number_of_fires': 325}
# {'_id': 108, 'date': '19/04/2017', 'number_of_fires': 50}
# {'_id': 109, 'date': '20/04/2017', 'number_of_fires': 31}
# {'_id': 110, 'date': '21/04/2017', 'number_of_fires': 0}
# {'_id': 111, 'date': '22/04/2017', 'number_of_fires': 2}
# {'_id': 112, 'date': '23/04/2017', 'number_of_fires': 19}
# {'_id': 113, 'date': '24/04/2017', 'number_of_fires': 8}
# {'_id': 114, 'date': '25/04/2017', 'number_of_fires': 3}
# {'_id': 115, 'date': '26/04/2017', 'number_of_fires': 1}
# {'_id': 116, 'date': '27/04/2017', 'number_of_fires': 0}
# {'_id': 117, 'date': '28/04/2017', 'number_of_fires': 0}
# {'_id': 118, 'date': '29/04/2017', 'number_of_fires': 3}
# {'_id': 119, 'date': '30/04/2017', 'number_of_fires': 0}
# {'_id': 120, 'date': '1/05/2017', 'number_of_fires': 20}
# {'_id': 121, 'date': '2/05/2017', 'number_of_fires': 10}
# {'_id': 122, 'date': '3/05/2017', 'number_of_fires': 64}
# {'_id': 123, 'date': '4/05/2017', 'number_of_fires': 135}
# {'_id': 124, 'date': '5/05/2017', 'number_of_fires': 31}
# {'_id': 125, 'date': '6/05/2017', 'number_of_fires': 17}
# {'_id': 126, 'date': '7/05/2017', 'number_of_fires': 3}
# {'_id': 127, 'date': '8/05/2017', 'number_of_fires': 24}
# {'_id': 128, 'date': '9/05/2017', 'number_of_fires': 13}
# {'_id': 129, 'date': '10/05/2017', 'number_of_fires': 114}
# {'_id': 130, 'date': '11/05/2017', 'number_of_fires': 19}
# {'_id': 131, 'date': '12/05/2017', 'number_of_fires': 10}
# {'_id': 132, 'date': '13/05/2017', 'number_of_fires': 54}
# {'_id': 133, 'date': '14/05/2017', 'number_of_fires': 1}
# {'_id': 134, 'date': '15/05/2017', 'number_of_fires': 102}
# {'_id': 135, 'date': '16/05/2017', 'number_of_fires': 3}
# {'_id': 136, 'date': '17/05/2017', 'number_of_fires': 1}
# {'_id': 137, 'date': '18/05/2017', 'number_of_fires': 7}
# {'_id': 138, 'date': '19/05/2017', 'number_of_fires': 0}
# {'_id': 139, 'date': '20/05/2017', 'number_of_fires': 0}
# {'_id': 140, 'date': '21/05/2017', 'number_of_fires': 0}
# {'_id': 141, 'date': '22/05/2017', 'number_of_fires': 33}
# {'_id': 142, 'date': '23/05/2017', 'number_of_fires': 5}
# {'_id': 143, 'date': '24/05/2017', 'number_of_fires': 3}
# {'_id': 144, 'date': '25/05/2017', 'number_of_fires': 0}
# {'_id': 145, 'date': '26/05/2017', 'number_of_fires': 4}
# {'_id': 146, 'date': '27/05/2017', 'number_of_fires': 0}
# {'_id': 147, 'date': '28/05/2017', 'number_of_fires': 0}
# {'_id': 148, 'date': '29/05/2017', 'number_of_fires': 0}
# {'_id': 149, 'date': '30/05/2017', 'number_of_fires': 0}
# {'_id': 150, 'date': '31/05/2017', 'number_of_fires': 0}
# {'_id': 151, 'date': '1/06/2017', 'number_of_fires': 2}
# {'_id': 152, 'date': '2/06/2017', 'number_of_fires': 11}
# {'_id': 153, 'date': '3/06/2017', 'number_of_fires': 2}
# {'_id': 154, 'date': '4/06/2017', 'number_of_fires': 9}
# {'_id': 155, 'date': '5/06/2017', 'number_of_fires': 0}
# {'_id': 156, 'date': '6/06/2017', 'number_of_fires': 0}
# {'_id': 157, 'date': '7/06/2017', 'number_of_fires': 14}
# {'_id': 158, 'date': '8/06/2017', 'number_of_fires': 0}
# {'_id': 159, 'date': '9/06/2017', 'number_of_fires': 3}
# {'_id': 160, 'date': '10/06/2017', 'number_of_fires': 0}
# {'_id': 161, 'date': '11/06/2017', 'number_of_fires': 2}
# {'_id': 162, 'date': '12/06/2017', 'number_of_fires': 0}
# {'_id': 163, 'date': '13/06/2017', 'number_of_fires': 1}
# {'_id': 164, 'date': '14/06/2017', 'number_of_fires': 4}
# {'_id': 165, 'date': '15/06/2017', 'number_of_fires': 0}
# {'_id': 166, 'date': '16/06/2017', 'number_of_fires': 2}
# {'_id': 167, 'date': '17/06/2017', 'number_of_fires': 0}
# {'_id': 168, 'date': '18/06/2017', 'number_of_fires': 2}
# {'_id': 169, 'date': '19/06/2017', 'number_of_fires': 0}
# {'_id': 170, 'date': '20/06/2017', 'number_of_fires': 6}
# {'_id': 171, 'date': '21/06/2017', 'number_of_fires': 0}
# {'_id': 172, 'date': '22/06/2017', 'number_of_fires': 1}
# {'_id': 173, 'date': '23/06/2017', 'number_of_fires': 0}
# {'_id': 174, 'date': '24/06/2017', 'number_of_fires': 0}
# {'_id': 175, 'date': '25/06/2017', 'number_of_fires': 0}
# {'_id': 176, 'date': '26/06/2017', 'number_of_fires': 0}
# {'_id': 177, 'date': '27/06/2017', 'number_of_fires': 0}
# {'_id': 178, 'date': '28/06/2017', 'number_of_fires': 0}
# {'_id': 179, 'date': '29/06/2017', 'number_of_fires': 0}
# {'_id': 180, 'date': '30/06/2017', 'number_of_fires': 6}
# {'_id': 181, 'date': '1/07/2017', 'number_of_fires': 4}
# {'_id': 182, 'date': '2/07/2017', 'number_of_fires': 8}
# {'_id': 183, 'date': '3/07/2017', 'number_of_fires': 0}
# {'_id': 184, 'date': '4/07/2017', 'number_of_fires': 1}
# {'_id': 185, 'date': '5/07/2017', 'number_of_fires': 1}
# {'_id': 186, 'date': '6/07/2017', 'number_of_fires': 3}
# {'_id': 187, 'date': '7/07/2017', 'number_of_fires': 0}
# {'_id': 188, 'date': '8/07/2017', 'number_of_fires': 0}
# {'_id': 189, 'date': '9/07/2017', 'number_of_fires': 0}
# {'_id': 190, 'date': '10/07/2017', 'number_of_fires': 0}
# {'_id': 191, 'date': '11/07/2017', 'number_of_fires': 0}
# {'_id': 192, 'date': '12/07/2017', 'number_of_fires': 0}
# {'_id': 193, 'date': '13/07/2017', 'number_of_fires': 0}
# {'_id': 194, 'date': '14/07/2017', 'number_of_fires': 2}
# {'_id': 195, 'date': '15/07/2017', 'number_of_fires': 0}
# {'_id': 196, 'date': '16/07/2017', 'number_of_fires': 0}
# {'_id': 197, 'date': '17/07/2017', 'number_of_fires': 0}
# {'_id': 198, 'date': '18/07/2017', 'number_of_fires': 0}
# {'_id': 199, 'date': '19/07/2017', 'number_of_fires': 0}
# {'_id': 200, 'date': '20/07/2017', 'number_of_fires': 0}
# {'_id': 201, 'date': '21/07/2017', 'number_of_fires': 0}
# {'_id': 202, 'date': '22/07/2017', 'number_of_fires': 0}
# {'_id': 203, 'date': '23/07/2017', 'number_of_fires': 0}
# {'_id': 204, 'date': '24/07/2017', 'number_of_fires': 0}
# {'_id': 205, 'date': '25/07/2017', 'number_of_fires': 0}
# {'_id': 206, 'date': '26/07/2017', 'number_of_fires': 0}
# {'_id': 207, 'date': '27/07/2017', 'number_of_fires': 0}
# {'_id': 208, 'date': '28/07/2017', 'number_of_fires': 0}
# {'_id': 209, 'date': '29/07/2017', 'number_of_fires': 2}
# {'_id': 210, 'date': '30/07/2017', 'number_of_fires': 0}
# {'_id': 211, 'date': '31/07/2017', 'number_of_fires': 2}
# {'_id': 212, 'date': '1/08/2017', 'number_of_fires': 2}
# {'_id': 213, 'date': '2/08/2017', 'number_of_fires': 2}
# {'_id': 214, 'date': '3/08/2017', 'number_of_fires': 0}
# {'_id': 215, 'date': '4/08/2017', 'number_of_fires': 0}
# {'_id': 216, 'date': '5/08/2017', 'number_of_fires': 1}
# {'_id': 217, 'date': '6/08/2017', 'number_of_fires': 0}
# {'_id': 218, 'date': '7/08/2017', 'number_of_fires': 0}
# {'_id': 219, 'date': '8/08/2017', 'number_of_fires': 0}
# {'_id': 220, 'date': '9/08/2017', 'number_of_fires': 0}
# {'_id': 221, 'date': '10/08/2017', 'number_of_fires': 1}
# {'_id': 222, 'date': '11/08/2017', 'number_of_fires': 0}
# {'_id': 223, 'date': '12/08/2017', 'number_of_fires': 0}
# {'_id': 224, 'date': '13/08/2017', 'number_of_fires': 9}
# {'_id': 225, 'date': '14/08/2017', 'number_of_fires': 5}
# {'_id': 226, 'date': '15/08/2017', 'number_of_fires': 0}
# {'_id': 227, 'date': '16/08/2017', 'number_of_fires': 0}
# {'_id': 228, 'date': '17/08/2017', 'number_of_fires': 0}
# {'_id': 229, 'date': '18/08/2017', 'number_of_fires': 0}
# {'_id': 230, 'date': '19/08/2017', 'number_of_fires': 0}
# {'_id': 231, 'date': '20/08/2017', 'number_of_fires': 0}
# {'_id': 232, 'date': '21/08/2017', 'number_of_fires': 0}
# {'_id': 233, 'date': '22/08/2017', 'number_of_fires': 0}
# {'_id': 234, 'date': '23/08/2017', 'number_of_fires': 0}
# {'_id': 235, 'date': '24/08/2017', 'number_of_fires': 0}
# {'_id': 236, 'date': '25/08/2017', 'number_of_fires': 0}
# {'_id': 237, 'date': '26/08/2017', 'number_of_fires': 0}
# {'_id': 238, 'date': '27/08/2017', 'number_of_fires': 0}
# {'_id': 239, 'date': '28/08/2017', 'number_of_fires': 0}
# {'_id': 240, 'date': '29/08/2017', 'number_of_fires': 0}
# {'_id': 241, 'date': '30/08/2017', 'number_of_fires': 0}
# {'_id': 242, 'date': '31/08/2017', 'number_of_fires': 0}
# {'_id': 243, 'date': '1/09/2017', 'number_of_fires': 0}
# {'_id': 244, 'date': '2/09/2017', 'number_of_fires': 0}
# {'_id': 245, 'date': '3/09/2017', 'number_of_fires': 0}
# {'_id': 246, 'date': '4/09/2017', 'number_of_fires': 0}
# {'_id': 247, 'date': '5/09/2017', 'number_of_fires': 0}
# {'_id': 248, 'date': '6/09/2017', 'number_of_fires': 0}
# {'_id': 249, 'date': '7/09/2017', 'number_of_fires': 0}
# {'_id': 250, 'date': '8/09/2017', 'number_of_fires': 0}
# {'_id': 251, 'date': '9/09/2017', 'number_of_fires': 0}
# {'_id': 252, 'date': '10/09/2017', 'number_of_fires': 4}
# {'_id': 253, 'date': '11/09/2017', 'number_of_fires': 0}
# {'_id': 254, 'date': '12/09/2017', 'number_of_fires': 0}
# {'_id': 255, 'date': '13/09/2017', 'number_of_fires': 0}
# {'_id': 256, 'date': '14/09/2017', 'number_of_fires': 0}
# {'_id': 257, 'date': '15/09/2017', 'number_of_fires': 0}
# {'_id': 258, 'date': '16/09/2017', 'number_of_fires': 0}
# {'_id': 259, 'date': '17/09/2017', 'number_of_fires': 0}
# {'_id': 260, 'date': '18/09/2017', 'number_of_fires': 0}
# {'_id': 261, 'date': '19/09/2017', 'number_of_fires': 0}
# {'_id': 262, 'date': '20/09/2017', 'number_of_fires': 5}
# {'_id': 263, 'date': '21/09/2017', 'number_of_fires': 2}
# {'_id': 264, 'date': '22/09/2017', 'number_of_fires': 1}
# {'_id': 265, 'date': '23/09/2017', 'number_of_fires': 23}
# {'_id': 266, 'date': '24/09/2017', 'number_of_fires': 28}
# {'_id': 267, 'date': '25/09/2017', 'number_of_fires': 0}
# {'_id': 268, 'date': '26/09/2017', 'number_of_fires': 1}
# {'_id': 269, 'date': '27/09/2017', 'number_of_fires': 7}
# {'_id': 270, 'date': '28/09/2017', 'number_of_fires': 0}
# {'_id': 271, 'date': '29/09/2017', 'number_of_fires': 2}
# {'_id': 272, 'date': '30/09/2017', 'number_of_fires': 0}
# {'_id': 273, 'date': '1/10/2017', 'number_of_fires': 8}
# {'_id': 274, 'date': '2/10/2017', 'number_of_fires': 7}
# {'_id': 275, 'date': '3/10/2017', 'number_of_fires': 18}
# {'_id': 276, 'date': '4/10/2017', 'number_of_fires': 5}
# {'_id': 277, 'date': '5/10/2017', 'number_of_fires': 0}
# {'_id': 278, 'date': '6/10/2017', 'number_of_fires': 2}
# {'_id': 279, 'date': '7/10/2017', 'number_of_fires': 1}
# {'_id': 280, 'date': '8/10/2017', 'number_of_fires': 1}
# {'_id': 281, 'date': '9/10/2017', 'number_of_fires': 1}
# {'_id': 282, 'date': '10/10/2017', 'number_of_fires': 3}
# {'_id': 283, 'date': '11/10/2017', 'number_of_fires': 0}
# {'_id': 284, 'date': '12/10/2017', 'number_of_fires': 0}
# {'_id': 285, 'date': '13/10/2017', 'number_of_fires': 0}
# {'_id': 286, 'date': '14/10/2017', 'number_of_fires': 0}
# {'_id': 287, 'date': '15/10/2017', 'number_of_fires': 3}
# {'_id': 288, 'date': '16/10/2017', 'number_of_fires': 1}
# {'_id': 289, 'date': '17/10/2017', 'number_of_fires': 5}
# {'_id': 290, 'date': '18/10/2017', 'number_of_fires': 6}
# {'_id': 291, 'date': '19/10/2017', 'number_of_fires': 0}
# {'_id': 292, 'date': '20/10/2017', 'number_of_fires': 3}
# {'_id': 293, 'date': '21/10/2017', 'number_of_fires': 4}
# {'_id': 294, 'date': '22/10/2017', 'number_of_fires': 0}
# {'_id': 295, 'date': '23/10/2017', 'number_of_fires': 1}
# {'_id': 296, 'date': '24/10/2017', 'number_of_fires': 0}
# {'_id': 297, 'date': '25/10/2017', 'number_of_fires': 0}
# {'_id': 298, 'date': '26/10/2017', 'number_of_fires': 5}
# {'_id': 299, 'date': '27/10/2017', 'number_of_fires': 5}
# {'_id': 300, 'date': '28/10/2017', 'number_of_fires': 1}
# {'_id': 301, 'date': '29/10/2017', 'number_of_fires': 0}
# {'_id': 302, 'date': '30/10/2017', 'number_of_fires': 0}
# {'_id': 303, 'date': '31/10/2017', 'number_of_fires': 0}
# {'_id': 304, 'date': '1/11/2017', 'number_of_fires': 0}
# {'_id': 305, 'date': '2/11/2017', 'number_of_fires': 0}
# {'_id': 306, 'date': '3/11/2017', 'number_of_fires': 0}
# {'_id': 307, 'date': '4/11/2017', 'number_of_fires': 0}
# {'_id': 308, 'date': '5/11/2017', 'number_of_fires': 4}
# {'_id': 309, 'date': '6/11/2017', 'number_of_fires': 0}
# {'_id': 310, 'date': '7/11/2017', 'number_of_fires': 0}
# {'_id': 311, 'date': '8/11/2017', 'number_of_fires': 2}
# {'_id': 312, 'date': '9/11/2017', 'number_of_fires': 10}
# {'_id': 313, 'date': '10/11/2017', 'number_of_fires': 0}
# {'_id': 314, 'date': '11/11/2017', 'number_of_fires': 4}
# {'_id': 315, 'date': '12/11/2017', 'number_of_fires': 5}
# {'_id': 316, 'date': '13/11/2017', 'number_of_fires': 5}
# {'_id': 317, 'date': '14/11/2017', 'number_of_fires': 3}
# {'_id': 318, 'date': '15/11/2017', 'number_of_fires': 0}
# {'_id': 319, 'date': '16/11/2017', 'number_of_fires': 0}
# {'_id': 320, 'date': '17/11/2017', 'number_of_fires': 0}
# {'_id': 321, 'date': '18/11/2017', 'number_of_fires': 0}
# {'_id': 322, 'date': '19/11/2017', 'number_of_fires': 0}
# {'_id': 323, 'date': '20/11/2017', 'number_of_fires': 0}
# {'_id': 324, 'date': '21/11/2017', 'number_of_fires': 1}
# {'_id': 325, 'date': '22/11/2017', 'number_of_fires': 2}
# {'_id': 326, 'date': '23/11/2017', 'number_of_fires': 5}
# {'_id': 327, 'date': '24/11/2017', 'number_of_fires': 0}
# {'_id': 328, 'date': '25/11/2017', 'number_of_fires': 0}
# {'_id': 329, 'date': '26/11/2017', 'number_of_fires': 0}
# {'_id': 330, 'date': '27/11/2017', 'number_of_fires': 0}
# {'_id': 331, 'date': '28/11/2017', 'number_of_fires': 1}
# {'_id': 332, 'date': '29/11/2017', 'number_of_fires': 8}
# {'_id': 333, 'date': '30/11/2017', 'number_of_fires': 31}
# {'_id': 334, 'date': '1/12/2017', 'number_of_fires': 0}
# {'_id': 335, 'date': '2/12/2017', 'number_of_fires': 0}
# {'_id': 336, 'date': '3/12/2017', 'number_of_fires': 0}
# {'_id': 337, 'date': '4/12/2017', 'number_of_fires': 0}
# {'_id': 338, 'date': '5/12/2017', 'number_of_fires': 0}
# {'_id': 339, 'date': '6/12/2017', 'number_of_fires': 0}
# {'_id': 340, 'date': '7/12/2017', 'number_of_fires': 0}
# {'_id': 341, 'date': '8/12/2017', 'number_of_fires': 5}
# {'_id': 342, 'date': '9/12/2017', 'number_of_fires': 4}
# {'_id': 343, 'date': '10/12/2017', 'number_of_fires': 2}
# {'_id': 344, 'date': '11/12/2017', 'number_of_fires': 0}
# {'_id': 345, 'date': '12/12/2017', 'number_of_fires': 1}
# {'_id': 346, 'date': '13/12/2017', 'number_of_fires': 1}
# {'_id': 347, 'date': '14/12/2017', 'number_of_fires': 1}
# {'_id': 348, 'date': '15/12/2017', 'number_of_fires': 4}
# {'_id': 349, 'date': '16/12/2017', 'number_of_fires': 15}
# {'_id': 350, 'date': '17/12/2017', 'number_of_fires': 0}
# {'_id': 351, 'date': '18/12/2017', 'number_of_fires': 0}
# {'_id': 352, 'date': '19/12/2017', 'number_of_fires': 0}
# {'_id': 353, 'date': '20/12/2017', 'number_of_fires': 0}
# {'_id': 354, 'date': '21/12/2017', 'number_of_fires': 1}
# {'_id': 355, 'date': '22/12/2017', 'number_of_fires': 0}
# {'_id': 356, 'date': '23/12/2017', 'number_of_fires': 0}
# {'_id': 357, 'date': '24/12/2017', 'number_of_fires': 1}
# {'_id': 358, 'date': '25/12/2017', 'number_of_fires': 1}
# {'_id': 359, 'date': '26/12/2017', 'number_of_fires': 0}
# {'_id': 360, 'date': '27/12/2017', 'number_of_fires': 4}
# {'_id': 361, 'date': '28/12/2017', 'number_of_fires': 0}
# {'_id': 362, 'date': '29/12/2017', 'number_of_fires': 0}
# {'_id': 363, 'date': '30/12/2017', 'number_of_fires': 0}
# {'_id': 364, 'date': '31/12/2017', 'number_of_fires': 0}
# {'_id': 365, 'date': '1/01/2018', 'number_of_fires': 0}

# %% [markdown]
# ## 14. (2G) Find the Average Surface Temperature for Each Day

# %%
for i in db.climate.find({'hotspot': {'$not': {'$size': 0}}}, 
                         {'date': 1, 
                          'hotspot.surface_temperature_celsius': 1, 
                          '_id': 1
                         }):       
    pprint({
        '_id': i['_id'],
        'date': i['date'],
        'average_surface_temperature': round(sum(j['surface_temperature_celsius'] for j in i['hotspot']) / len(i['hotspot']),
                                            2)
    })
# Out:
# {'_id': 64, 'average_surface_temperature': 60.5, 'date': '6/03/2017'}
# {'_id': 65, 'average_surface_temperature': 64.0, 'date': '7/03/2017'}
# {'_id': 66, 'average_surface_temperature': 51.5, 'date': '8/03/2017'}
# {'_id': 67, 'average_surface_temperature': 46.67, 'date': '9/03/2017'}
# {'_id': 68, 'average_surface_temperature': 69.38, 'date': '10/03/2017'}
# {'_id': 70, 'average_surface_temperature': 88.2, 'date': '12/03/2017'}
# {'_id': 71, 'average_surface_temperature': 38.5, 'date': '13/03/2017'}
# {'_id': 72, 'average_surface_temperature': 65.6, 'date': '14/03/2017'}
# {'_id': 73, 'average_surface_temperature': 46.0, 'date': '15/03/2017'}
# {'_id': 75, 'average_surface_temperature': 59.5, 'date': '17/03/2017'}
# {'_id': 76, 'average_surface_temperature': 79.33, 'date': '18/03/2017'}
# {'_id': 77, 'average_surface_temperature': 65.57, 'date': '19/03/2017'}
# {'_id': 82, 'average_surface_temperature': 49.0, 'date': '24/03/2017'}
# {'_id': 83, 'average_surface_temperature': 66.0, 'date': '25/03/2017'}
# {'_id': 84, 'average_surface_temperature': 56.88, 'date': '26/03/2017'}
# {'_id': 86, 'average_surface_temperature': 60.93, 'date': '28/03/2017'}
# {'_id': 87, 'average_surface_temperature': 51.0, 'date': '29/03/2017'}
# {'_id': 89, 'average_surface_temperature': 48.73, 'date': '31/03/2017'}
# {'_id': 90, 'average_surface_temperature': 46.71, 'date': '1/04/2017'}
# {'_id': 91, 'average_surface_temperature': 45.2, 'date': '2/04/2017'}
# {'_id': 92, 'average_surface_temperature': 58.44, 'date': '3/04/2017'}
# {'_id': 93, 'average_surface_temperature': 62.57, 'date': '4/04/2017'}
# {'_id': 94, 'average_surface_temperature': 53.14, 'date': '5/04/2017'}
# {'_id': 95, 'average_surface_temperature': 61.71, 'date': '6/04/2017'}
# {'_id': 96, 'average_surface_temperature': 50.69, 'date': '7/04/2017'}
# {'_id': 97, 'average_surface_temperature': 60.75, 'date': '8/04/2017'}
# {'_id': 100, 'average_surface_temperature': 46.29, 'date': '11/04/2017'}
# {'_id': 101, 'average_surface_temperature': 52.7, 'date': '12/04/2017'}
# {'_id': 102, 'average_surface_temperature': 58.58, 'date': '13/04/2017'}
# {'_id': 103, 'average_surface_temperature': 61.94, 'date': '14/04/2017'}
# {'_id': 104, 'average_surface_temperature': 59.58, 'date': '15/04/2017'}
# {'_id': 105, 'average_surface_temperature': 48.72, 'date': '16/04/2017'}
# {'_id': 106, 'average_surface_temperature': 50.92, 'date': '17/04/2017'}
# {'_id': 107, 'average_surface_temperature': 53.37, 'date': '18/04/2017'}
# {'_id': 108, 'average_surface_temperature': 54.16, 'date': '19/04/2017'}
# {'_id': 109, 'average_surface_temperature': 56.58, 'date': '20/04/2017'}
# {'_id': 111, 'average_surface_temperature': 54.5, 'date': '22/04/2017'}
# {'_id': 112, 'average_surface_temperature': 53.89, 'date': '23/04/2017'}
# {'_id': 113, 'average_surface_temperature': 59.38, 'date': '24/04/2017'}
# {'_id': 114, 'average_surface_temperature': 48.67, 'date': '25/04/2017'}
# {'_id': 115, 'average_surface_temperature': 34.0, 'date': '26/04/2017'}
# {'_id': 118, 'average_surface_temperature': 63.0, 'date': '29/04/2017'}
# {'_id': 120, 'average_surface_temperature': 68.4, 'date': '1/05/2017'}
# {'_id': 121, 'average_surface_temperature': 55.6, 'date': '2/05/2017'}
# {'_id': 122, 'average_surface_temperature': 56.8, 'date': '3/05/2017'}
# {'_id': 123, 'average_surface_temperature': 56.81, 'date': '4/05/2017'}
# {'_id': 124, 'average_surface_temperature': 51.71, 'date': '5/05/2017'}
# {'_id': 125, 'average_surface_temperature': 57.53, 'date': '6/05/2017'}
# {'_id': 126, 'average_surface_temperature': 50.33, 'date': '7/05/2017'}
# {'_id': 127, 'average_surface_temperature': 56.29, 'date': '8/05/2017'}
# {'_id': 128, 'average_surface_temperature': 42.46, 'date': '9/05/2017'}
# {'_id': 129, 'average_surface_temperature': 52.87, 'date': '10/05/2017'}
# {'_id': 130, 'average_surface_temperature': 59.37, 'date': '11/05/2017'}
# {'_id': 131, 'average_surface_temperature': 51.5, 'date': '12/05/2017'}
# {'_id': 132, 'average_surface_temperature': 58.61, 'date': '13/05/2017'}
# {'_id': 133, 'average_surface_temperature': 49.0, 'date': '14/05/2017'}
# {'_id': 134, 'average_surface_temperature': 53.95, 'date': '15/05/2017'}
# {'_id': 135, 'average_surface_temperature': 39.67, 'date': '16/05/2017'}
# {'_id': 136, 'average_surface_temperature': 52.0, 'date': '17/05/2017'}
# {'_id': 137, 'average_surface_temperature': 44.14, 'date': '18/05/2017'}
# {'_id': 141, 'average_surface_temperature': 54.48, 'date': '22/05/2017'}
# {'_id': 142, 'average_surface_temperature': 51.2, 'date': '23/05/2017'}
# {'_id': 143, 'average_surface_temperature': 40.33, 'date': '24/05/2017'}
# {'_id': 145, 'average_surface_temperature': 49.5, 'date': '26/05/2017'}
# {'_id': 151, 'average_surface_temperature': 54.0, 'date': '1/06/2017'}
# {'_id': 152, 'average_surface_temperature': 47.73, 'date': '2/06/2017'}
# {'_id': 153, 'average_surface_temperature': 47.0, 'date': '3/06/2017'}
# {'_id': 154, 'average_surface_temperature': 52.22, 'date': '4/06/2017'}
# {'_id': 157, 'average_surface_temperature': 51.86, 'date': '7/06/2017'}
# {'_id': 159, 'average_surface_temperature': 49.0, 'date': '9/06/2017'}
# {'_id': 161, 'average_surface_temperature': 41.5, 'date': '11/06/2017'}
# {'_id': 163, 'average_surface_temperature': 41.0, 'date': '13/06/2017'}
# {'_id': 164, 'average_surface_temperature': 53.25, 'date': '14/06/2017'}
# {'_id': 166, 'average_surface_temperature': 42.5, 'date': '16/06/2017'}
# {'_id': 168, 'average_surface_temperature': 42.0, 'date': '18/06/2017'}
# {'_id': 170, 'average_surface_temperature': 71.17, 'date': '20/06/2017'}
# {'_id': 172, 'average_surface_temperature': 46.0, 'date': '22/06/2017'}
# {'_id': 180, 'average_surface_temperature': 44.33, 'date': '30/06/2017'}
# {'_id': 181, 'average_surface_temperature': 30.5, 'date': '1/07/2017'}
# {'_id': 182, 'average_surface_temperature': 43.5, 'date': '2/07/2017'}
# {'_id': 184, 'average_surface_temperature': 40.0, 'date': '4/07/2017'}
# {'_id': 185, 'average_surface_temperature': 45.0, 'date': '5/07/2017'}
# {'_id': 186, 'average_surface_temperature': 56.0, 'date': '6/07/2017'}
# {'_id': 194, 'average_surface_temperature': 41.5, 'date': '14/07/2017'}
# {'_id': 209, 'average_surface_temperature': 48.0, 'date': '29/07/2017'}
# {'_id': 211, 'average_surface_temperature': 47.0, 'date': '31/07/2017'}
# {'_id': 212, 'average_surface_temperature': 58.0, 'date': '1/08/2017'}
# {'_id': 213, 'average_surface_temperature': 63.5, 'date': '2/08/2017'}
# {'_id': 216, 'average_surface_temperature': 40.0, 'date': '5/08/2017'}
# {'_id': 221, 'average_surface_temperature': 63.0, 'date': '10/08/2017'}
# {'_id': 224, 'average_surface_temperature': 49.0, 'date': '13/08/2017'}
# {'_id': 225, 'average_surface_temperature': 40.8, 'date': '14/08/2017'}
# {'_id': 252, 'average_surface_temperature': 56.5, 'date': '10/09/2017'}
# {'_id': 262, 'average_surface_temperature': 63.6, 'date': '20/09/2017'}
# {'_id': 263, 'average_surface_temperature': 40.5, 'date': '21/09/2017'}
# {'_id': 264, 'average_surface_temperature': 45.0, 'date': '22/09/2017'}
# {'_id': 265, 'average_surface_temperature': 52.74, 'date': '23/09/2017'}
# {'_id': 266, 'average_surface_temperature': 53.57, 'date': '24/09/2017'}
# {'_id': 268, 'average_surface_temperature': 33.0, 'date': '26/09/2017'}
# {'_id': 269, 'average_surface_temperature': 49.71, 'date': '27/09/2017'}
# {'_id': 271, 'average_surface_temperature': 43.0, 'date': '29/09/2017'}
# {'_id': 273, 'average_surface_temperature': 48.25, 'date': '1/10/2017'}
# {'_id': 274, 'average_surface_temperature': 43.57, 'date': '2/10/2017'}
# {'_id': 275, 'average_surface_temperature': 50.0, 'date': '3/10/2017'}
# {'_id': 276, 'average_surface_temperature': 49.0, 'date': '4/10/2017'}
# {'_id': 278, 'average_surface_temperature': 44.0, 'date': '6/10/2017'}
# {'_id': 279, 'average_surface_temperature': 42.0, 'date': '7/10/2017'}
# {'_id': 280, 'average_surface_temperature': 41.0, 'date': '8/10/2017'}
# {'_id': 281, 'average_surface_temperature': 44.0, 'date': '9/10/2017'}
# {'_id': 282, 'average_surface_temperature': 53.33, 'date': '10/10/2017'}
# {'_id': 287, 'average_surface_temperature': 72.67, 'date': '15/10/2017'}
# {'_id': 288, 'average_surface_temperature': 36.0, 'date': '16/10/2017'}
# {'_id': 289, 'average_surface_temperature': 51.6, 'date': '17/10/2017'}
# {'_id': 290, 'average_surface_temperature': 52.17, 'date': '18/10/2017'}
# {'_id': 292, 'average_surface_temperature': 50.0, 'date': '20/10/2017'}
# {'_id': 293, 'average_surface_temperature': 51.25, 'date': '21/10/2017'}
# {'_id': 295, 'average_surface_temperature': 38.0, 'date': '23/10/2017'}
# {'_id': 298, 'average_surface_temperature': 44.6, 'date': '26/10/2017'}
# {'_id': 299, 'average_surface_temperature': 50.4, 'date': '27/10/2017'}
# {'_id': 300, 'average_surface_temperature': 56.0, 'date': '28/10/2017'}
# {'_id': 308, 'average_surface_temperature': 58.5, 'date': '5/11/2017'}
# {'_id': 311, 'average_surface_temperature': 45.5, 'date': '8/11/2017'}
# {'_id': 312, 'average_surface_temperature': 61.3, 'date': '9/11/2017'}
# {'_id': 314, 'average_surface_temperature': 46.25, 'date': '11/11/2017'}
# {'_id': 315, 'average_surface_temperature': 53.0, 'date': '12/11/2017'}
# {'_id': 316, 'average_surface_temperature': 47.0, 'date': '13/11/2017'}
# {'_id': 317, 'average_surface_temperature': 52.0, 'date': '14/11/2017'}
# {'_id': 324, 'average_surface_temperature': 59.0, 'date': '21/11/2017'}
# {'_id': 325, 'average_surface_temperature': 61.5, 'date': '22/11/2017'}
# {'_id': 326, 'average_surface_temperature': 58.8, 'date': '23/11/2017'}
# {'_id': 331, 'average_surface_temperature': 42.0, 'date': '28/11/2017'}
# {'_id': 332, 'average_surface_temperature': 60.62, 'date': '29/11/2017'}
# {'_id': 333, 'average_surface_temperature': 52.42, 'date': '30/11/2017'}
# {'_id': 341, 'average_surface_temperature': 50.6, 'date': '8/12/2017'}
# {'_id': 342, 'average_surface_temperature': 58.25, 'date': '9/12/2017'}
# {'_id': 343, 'average_surface_temperature': 46.0, 'date': '10/12/2017'}
# {'_id': 345, 'average_surface_temperature': 44.0, 'date': '12/12/2017'}
# {'_id': 346, 'average_surface_temperature': 60.0, 'date': '13/12/2017'}
# {'_id': 347, 'average_surface_temperature': 70.0, 'date': '14/12/2017'}
# {'_id': 348, 'average_surface_temperature': 39.0, 'date': '15/12/2017'}
# {'_id': 349, 'average_surface_temperature': 57.8, 'date': '16/12/2017'}
# {'_id': 354, 'average_surface_temperature': 46.0, 'date': '21/12/2017'}
# {'_id': 357, 'average_surface_temperature': 32.0, 'date': '24/12/2017'}
# {'_id': 358, 'average_surface_temperature': 54.0, 'date': '25/12/2017'}
# {'_id': 360, 'average_surface_temperature': 62.75, 'date': '27/12/2017'}
